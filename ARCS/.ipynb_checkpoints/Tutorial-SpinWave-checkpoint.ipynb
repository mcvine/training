# %% [markdown]
# # Spin Wave Simulation

# %% [markdown]
# Instrument: ARCS
# * Ei=100meV
# * Fermi chopper: 600 Hz
# * T0: 120Hz
#
# Sample: some crystal
# * lattice parameters: 2, 2.5, 3        90 90 90
# * Orientation: u,v = [1 0 2] and  [1 0 0]
# * psi angles: -90, 90, step 2

# %% [markdown]
# ## Step 0. some goodies

# %%
# %matplotlib notebook
from matplotlib import pyplot as plt
import numpy as np
import histogram.hdf as hh, histogram as H

# %% [markdown]
# ## Step 1. create dir structure

# %%
# Change this!!!
workdir = "/SNS/users/lj7/simulations/ARCS/spinwave-demo/"
# !mkdir -p {workdir}

# %%
# %cd {workdir}
# !ls
# Out:
# /SNS/users/lj7/simulations/ARCS/spinwave-demo

# %%
# !mkdir -p samples/X/sampleassembly
# !mkdir -p beam
# !mkdir -p scattering

# %%
# !find .
# Out:
# .
# ./samples
# ./samples/X
# ./samples/X/sampleassembly
# ./beam
# ./scattering

# %% [markdown]
# ## Step 2. obtain beam simulation

# %%
# !ln -s /SNS/users/lj7/simulations/ARCS/beam/100meV beam/100meV

# %%
# %cd beam/100meV
# Out:
# /SNS/users/lj7/simulations/ARCS/beam/100meV

# %%
# check
import histogram.hdf as hh
ie = hh.load("out/ienergy.h5")
plt.plot(ie.energy, ie.I)
# Out:
# <img src="data:image/png;base64,...">

# %% [markdown]
# ## Step 3. Create sample assembly

# %%
# %cd "{workdir}/samples/X/sampleassembly"
# Out:
# /SNS/users/lj7/simulations/ARCS/spinwave-demo/samples/X/sampleassembly

# %%
# %cp -a /SNS/users/lj7/simulations/samples/spinwave/* .

# %%
# %%file ./X.xyz
# 8
# 2 0 0    0 2.5 0  0 0 3
# V 0 0 0
# V 0 0 0
# V 0 0 0
# V 0 0 0
# V 0 0 0
# V 0 0 0
# V 0 0 0
# V 0 0 0
# Out:
# Overwriting ./X.xyz

# %%
# %%file ./X-scatterer.xml
# <?xml version="1.0"?>
#
# <!DOCTYPE scatterer>
#
# <!-- weights: absorption, scattering, transmission -->
# <homogeneous_scatterer
#   mcweights="0, 1, 0.1"
#   max_multiplescattering_loops="3"
#   >
#
#   <KernelContainer average="yes">
#
#     <E_Q_Kernel
# 	E_Q="0"
# 	S_Q="1"
# 	Qmin="0./angstrom"
# 	Qmax="16./angstrom"
# 	/>
#
#     <E_vQ_Kernel
# 	E_Q="pi:=3.1415926535897932; twopi:=2*pi; a:=2; b:=2.5; c:=3;
#     h:=a*Qx/twopi; k:=b*Qy/twopi; l:=c*Qz/twopi;
#     cospih2:=cos(h*pi)^2; cospil2:=cos(l*pi)^2; cospik2:=cos(k*pi)^2;
#     (80.^2*(1-cospih2)) ^ (0.5)"
# 	S_Q="1"
# 	Emax="80*meV"
# 	/>
#
#   </KernelContainer>
#
# </homogeneous_scatterer>
# Out:
# Overwriting ./X-scatterer.xml

# %%
a,b,c=2,2.5,3

from numpy import sin, cos, deg2rad
a1 = [a, 0, 0]
a2 = [0, b, 0]
a3 = [0, 0, c]

twopi = 2*np.pi
f = twopi/np.dot(a1, np.cross(a2, a3))
b1 = np.cross(a2,a3) * f
b2 = np.cross(a3,a1) * f
b3 = np.cross(a1,a2) * f
b1,b2,b3
# Out:
# (array([ 3.14159265,  0.        ,  0.        ]),
#  array([ 0.        ,  2.51327412,  0.        ]),
#  array([ 0.       ,  0.       ,  2.0943951]))

# %% [markdown]
# #### Orientation of the kernel
# Here we need to use the convention that z is along beam, y vertical up.
# The kernel has its own cartesian axis e’x e’y e’z. Because we know
# u = 102 v = 100
# , we have the basis vectors of the instrument coordinate system
#
#     ez along b1 + 2*b3
#     ex along b1
#
#
# So we have them in the reciprocal cartesian axis

# %%
ez = b1 + 2*b3; ez /= np.linalg.norm(ez)
ex1 = b1
ey = np.cross(ez, ex1); ey/=np.linalg.norm(ey)
ex = np.cross(ey, ez)
ex, ey, ez
# Out:
# (array([ 0.8,  0. , -0.6]), array([ 0.,  1.,  0.]), array([ 0.6,  0. ,  0.8]))

# %% [markdown]
# The rotation matrix is define as
# ```
#     ex.ex’ ex.ey’ ex.ez’
# R = ey.ex’ ey.ey’ ey.ez’
#     ez.ex’ ez.ey’ ez.ez’
# ```
# So

# %%
R = np.array([ ex, ey, ez ])
Rflat = R.copy(); Rflat.shape = -1,
R, Rflat
# Out:
# (array([[ 0.8,  0. , -0.6],
#         [ 0. ,  1. ,  0. ],
#         [ 0.6,  0. ,  0.8]]),
#  array([ 0.8,  0. , -0.6,  0. ,  1. ,  0. ,  0.6,  0. ,  0.8]))

# %% [markdown]
# Now we add an extra kernel parameter:

# %%
'orientation="%s"' % (','.join(str(e) for e in Rflat),)
# Out:
# 'orientation="0.8,0.0,-0.6,0.0,1.0,0.0,0.6,0.0,0.8"'

# %%
# modify X-scatterer.xml to specify the orientation

# %%
# %%file ./X-scatterer.xml
# <?xml version="1.0"?>
#
# <!DOCTYPE scatterer>
#
# <!-- weights: absorption, scattering, transmission -->
# <homogeneous_scatterer
#   mcweights="0, 1, 0.1"
#   max_multiplescattering_loops="3"
#   >
#
#   <KernelContainer average="yes">
#
#     <E_Q_Kernel
# 	E_Q="0"
# 	S_Q="1"
# 	Qmin="0./angstrom"
# 	Qmax="16./angstrom"
# 	/>
#
#     <E_vQ_Kernel
# 	E_Q="pi:=3.1415926535897932; twopi:=2*pi; a:=2; b:=2.5; c:=3;
#     h:=a*Qx/twopi; k:=b*Qy/twopi; l:=c*Qz/twopi;
#     cospih2:=cos(h*pi)^2; cospil2:=cos(l*pi)^2; cospik2:=cos(k*pi)^2;
#     (80.^2*(1-cospih2)) ^ (0.5)"
# 	S_Q="1"
# 	Emax="80*meV"
# 	orientation="0.8,0.0,-0.6,0.0,1.0,0.0,0.6,0.0,0.8"
# 	/>
#
#   </KernelContainer>
#
# </homogeneous_scatterer>
# Out:
# Overwriting ./X-scatterer.xml

# %%
# !cat X-scatterer.xml
# Out:
# <?xml version="1.0"?>
#
# <!DOCTYPE scatterer>
#
# <!-- weights: absorption, scattering, transmission -->
# <homogeneous_scatterer
#   mcweights="0, 1, 0.1"
#   max_multiplescattering_loops="3"
#   >
#
#   <KernelContainer average="yes">
#
#     <E_Q_Kernel
# 	E_Q="0"
# 	S_Q="1"
# 	Qmin="0./angstrom"
# 	Qmax="16./angstrom"
# 	/>
#
#     <E_vQ_Kernel
# 	E_Q="pi:=3.1415926535897932; twopi:=2*pi; a:=2; b:=2.5; c:=3;
#     h:=a*Qx/twopi; k:=b*Qy/twopi; l:=c*Qz/twopi;
#     cospih2:=cos(h*pi)^2; cospil2:=cos(l*pi)^2; cospik2:=cos(k*pi)^2;
#     (80.^2*(1-cospih2)) ^ (0.5)"
# 	S_Q="1"
# 	Emax="80*meV"
# 	orientation="0.8,0.0,-0.6,0.0,1.0,0.0,0.6,0.0,0.8"
# 	/>
#
#   </KernelContainer>
#
# </homogeneous_scatterer>

# %%
# !ls
# Out:
# dispersion-expression  sampleassembly.xml  X-scatterer.xml  X.xyz

# %% [markdown]
# ## Step 4. Scattering

# %%
# %cd "{workdir}/scattering"
# Out:
# /SNS/users/lj7/simulations/ARCS/spinwave-demo/scattering

# %%
# !rsync -a ~lj7/simulations/mcvine_workflow/DGS/ARCS/single-crystal/* ./
# !ls
# Out:
# scripts  template

# %%
# %cd template

# !ln -s ../../samples/X/sampleassembly

# !ln -s ../../beam/100meV beam

# %cd ..
# Out:
# /SNS/users/lj7/simulations/ARCS/spinwave-demo/scattering/template
# /SNS/users/lj7/simulations/ARCS/spinwave-demo/scattering

# %%
# %%file sim.yml
#
# cluster:
#   nodes: 10
# instrument:
#   name: arcs
# scatter:
#   ncount: 1e6
#   multiple_scattering: off
#   template: ./template
# Out:
# Overwriting sim.yml

# %%
# !./scripts/sim.py --angle=30.0
# Out:
# SAMPLE_ANGLE=30.0 time ./scatter &> log.scatter
# time ./create-nxs &> log.create-nxs
#
# real	2m23.532s
# user	17m6.067s
# sys	3m48.953s
# cp sim.nxs sim-30.0.nxs
# mcvine instruments arcs nxs populate_metadata --type=Ei --beam_outdir=beam/out --nxs=sim-30.0.nxs
# /SNS/users/lj7/software/miniconda2/envs/mcvine/lib/python2.7/site-packages/mcvine/deployment_info.py:41: UserWarning: Neither environment variable MCVINE_DIR nor DANSE_DIR was defined. Assumed that it is /SNS/users/lj7/software/miniconda2/envs/mcvine.
#   warnings.warn(msg)

# %%
# %%file sim.yml
#
# cluster:
#   nodes: 1
# instrument:
#   name: arcs
# scatter:
#   ncount: 1e6
#   multiple_scattering: off
#   template: ./template
# Out:
# Overwriting sim.yml

# %%
# %%file create-submit.py
import numpy as np
ostream = open('submit.sh', 'wt')
for a in np.arange(-90, 90.1, 3.):
    ostream.write('./scripts/sim.py --angle=%s &\n' % a)
    continue
ostream.close()
# Out:
# Overwriting create-submit.py

# %%
# !python ./create-submit.py

# %%
#!cat submit.sh

# %%
#!bash submit.sh

# %% [markdown]
# ## Step 5. Reduction

# %%
# %cd "{workdir}/scattering"
# !ls
# Out:
# /SNS/users/lj7/simulations/ARCS/spinwave-demo/scattering
# create-submit.py  work_18.0   work_-33.0  work_48.0   work_-63.0  work_78.0
# scripts		  work_-21.0  work_33.0   work_-51.0  work_63.0   work_-81.0
# sim.yml		  work_21.0   work_-36.0  work_51.0   work_-66.0  work_81.0
# submit.sh	  work_-24.0  work_36.0   work_-54.0  work_66.0   work_-84.0
# template	  work_24.0   work_-39.0  work_54.0   work_-69.0  work_84.0
# work_0.0	  work_-27.0  work_39.0   work_-57.0  work_69.0   work_-87.0
# work_-12.0	  work_27.0   work_-42.0  work_57.0   work_-72.0  work_87.0
# work_12.0	  work_-3.0   work_42.0   work_-6.0   work_72.0   work_-9.0
# work_-15.0	  work_3.0    work_-45.0  work_6.0    work_-75.0  work_9.0
# work_15.0	  work_-30.0  work_45.0   work_-60.0  work_75.0   work_-90.0
# work_-18.0	  work_30.0   work_-48.0  work_60.0   work_-78.0  work_90.0

# %% [markdown]
# First we reduce event-mode nexus data for each angle using Mantid

# %%
# check if there is reduced data
# !ls work_2.0/reduced*
# Out:
# ls: cannot access work_2.0/reduced*: No such file or directory

# %%
# reduce tof events to E events
# !./scripts/reduce/reduceKeepingEvents_batch.py -90,90.1,3. 100 0,90,0.5
# Out:
# work_-90.0 ['python', '../scripts/reduce/reduceKeepingEvents.py', 'sim--90.0.nxs', '-90.0', '100', '0,0.5,90', 'reduced_-90.0.nxs']
# work_-87.0 ['python', '../scripts/reduce/reduceKeepingEvents.py', 'sim--87.0.nxs', '-87.0', '100', '0,0.5,90', 'reduced_-87.0.nxs']
# work_-84.0 ['python', '../scripts/reduce/reduceKeepingEvents.py', 'sim--84.0.nxs', '-84.0', '100', '0,0.5,90', 'reduced_-84.0.nxs']
# work_-81.0 ['python', '../scripts/reduce/reduceKeepingEvents.py', 'sim--81.0.nxs', '-81.0', '100', '0,0.5,90', 'reduced_-81.0.nxs']
# work_-78.0 ['python', '../scripts/reduce/reduceKeepingEvents.py', 'sim--78.0.nxs', '-78.0', '100', '0,0.5,90', 'reduced_-78.0.nxs']
# work_-75.0 ['python', '../scripts/reduce/reduceKeepingEvents.py', 'sim--75.0.nxs', '-75.0', '100', '0,0.5,90', 'reduced_-75.0.nxs']
# work_-72.0 ['python', '../scripts/reduce/reduceKeepingEvents.py', 'sim--72.0.nxs', '-72.0', '100', '0,0.5,90', 'reduced_-72.0.nxs']
# work_-69.0 ['python', '../scripts/reduce/reduceKeepingEvents.py', 'sim--69.0.nxs', '-69.0', '100', '0,0.5,90', 'reduced_-69.0.nxs']
# work_-66.0 ['python', '../scripts/reduce/reduceKeepingEvents.py', 'sim--66.0.nxs', '-66.0', '100', '0,0.5,90', 'reduced_-66.0.nxs']
# work_-63.0 ['python', '../scripts/reduce/reduceKeepingEvents.py', 'sim--63.0.nxs', '-63.0', '100', '0,0.5,90', 'reduced_-63.0.nxs']
# work_-60.0 ['python', '../scripts/reduce/reduceKeepingEvents.py', 'sim--60.0.nxs', '-60.0', '100', '0,0.5,90', 'reduced_-60.0.nxs']
# work_-57.0 ['python', '../scripts/reduce/reduceKeepingEvents.py', 'sim--57.0.nxs', '-57.0', '100', '0,0.5,90', 'reduced_-57.0.nxs']
# work_-54.0 ['python', '../scripts/reduce/reduceKeepingEvents.py', 'sim--54.0.nxs', '-54.0', '100', '0,0.5,90', 'reduced_-54.0.nxs']
# work_-51.0 ['python', '../scripts/reduce/reduceKeepingEvents.py', 'sim--51.0.nxs', '-51.0', '100', '0,0.5,90', 'reduced_-51.0.nxs']
# work_-48.0 ['python', '../scripts/reduce/reduceKeepingEvents.py', 'sim--48.0.nxs', '-48.0', '100', '0,0.5,90', 'reduced_-48.0.nxs']
# work_-45.0 ['python', '../scripts/reduce/reduceKeepingEvents.py', 'sim--45.0.nxs', '-45.0', '100', '0,0.5,90', 'reduced_-45.0.nxs']
# work_-42.0 ['python', '../scripts/reduce/reduceKeepingEvents.py', 'sim--42.0.nxs', '-42.0', '100', '0,0.5,90', 'reduced_-42.0.nxs']
# work_-39.0 ['python', '../scripts/reduce/reduceKeepingEvents.py', 'sim--39.0.nxs', '-39.0', '100', '0,0.5,90', 'reduced_-39.0.nxs']
# work_-36.0 ['python', '../scripts/reduce/reduceKeepingEvents.py', 'sim--36.0.nxs', '-36.0', '100', '0,0.5,90', 'reduced_-36.0.nxs']
# work_-33.0 ['python', '../scripts/reduce/reduceKeepingEvents.py', 'sim--33.0.nxs', '-33.0', '100', '0,0.5,90', 'reduced_-33.0.nxs']
# work_-30.0 ['python', '../scripts/reduce/reduceKeepingEvents.py', 'sim--30.0.nxs', '-30.0', '100', '0,0.5,90', 'reduced_-30.0.nxs']
# work_-27.0 ['python', '../scripts/reduce/reduceKeepingEvents.py', 'sim--27.0.nxs', '-27.0', '100', '0,0.5,90', 'reduced_-27.0.nxs']
# work_-24.0 ['python', '../scripts/reduce/reduceKeepingEvents.py', 'sim--24.0.nxs', '-24.0', '100', '0,0.5,90', 'reduced_-24.0.nxs']
# work_-21.0 ['python', '../scripts/reduce/reduceKeepingEvents.py', 'sim--21.0.nxs', '-21.0', '100', '0,0.5,90', 'reduced_-21.0.nxs']
# work_-18.0 ['python', '../scripts/reduce/reduceKeepingEvents.py', 'sim--18.0.nxs', '-18.0', '100', '0,0.5,90', 'reduced_-18.0.nxs']
# work_-15.0 ['python', '../scripts/reduce/reduceKeepingEvents.py', 'sim--15.0.nxs', '-15.0', '100', '0,0.5,90', 'reduced_-15.0.nxs']
# work_-12.0 ['python', '../scripts/reduce/reduceKeepingEvents.py', 'sim--12.0.nxs', '-12.0', '100', '0,0.5,90', 'reduced_-12.0.nxs']
# work_-9.0 ['python', '../scripts/reduce/reduceKeepingEvents.py', 'sim--9.0.nxs', '-9.0', '100', '0,0.5,90', 'reduced_-9.0.nxs']
# work_-6.0 ['python', '../scripts/reduce/reduceKeepingEvents.py', 'sim--6.0.nxs', '-6.0', '100', '0,0.5,90', 'reduced_-6.0.nxs']
# work_-3.0 ['python', '../scripts/reduce/reduceKeepingEvents.py', 'sim--3.0.nxs', '-3.0', '100', '0,0.5,90', 'reduced_-3.0.nxs']
# work_0.0 ['python', '../scripts/reduce/reduceKeepingEvents.py', 'sim-0.0.nxs', '0.0', '100', '0,0.5,90', 'reduced_0.0.nxs']
# work_3.0 ['python', '../scripts/reduce/reduceKeepingEvents.py', 'sim-3.0.nxs', '3.0', '100', '0,0.5,90', 'reduced_3.0.nxs']
# work_6.0 ['python', '../scripts/reduce/reduceKeepingEvents.py', 'sim-6.0.nxs', '6.0', '100', '0,0.5,90', 'reduced_6.0.nxs']
# work_9.0 ['python', '../scripts/reduce/reduceKeepingEvents.py', 'sim-9.0.nxs', '9.0', '100', '0,0.5,90', 'reduced_9.0.nxs']
# work_12.0 ['python', '../scripts/reduce/reduceKeepingEvents.py', 'sim-12.0.nxs', '12.0', '100', '0,0.5,90', 'reduced_12.0.nxs']
# work_15.0 ['python', '../scripts/reduce/reduceKeepingEvents.py', 'sim-15.0.nxs', '15.0', '100', '0,0.5,90', 'reduced_15.0.nxs']
# work_18.0 ['python', '../scripts/reduce/reduceKeepingEvents.py', 'sim-18.0.nxs', '18.0', '100', '0,0.5,90', 'reduced_18.0.nxs']
# work_21.0 ['python', '../scripts/reduce/reduceKeepingEvents.py', 'sim-21.0.nxs', '21.0', '100', '0,0.5,90', 'reduced_21.0.nxs']
# work_24.0 ['python', '../scripts/reduce/reduceKeepingEvents.py', 'sim-24.0.nxs', '24.0', '100', '0,0.5,90', 'reduced_24.0.nxs']
# work_27.0 ['python', '../scripts/reduce/reduceKeepingEvents.py', 'sim-27.0.nxs', '27.0', '100', '0,0.5,90', 'reduced_27.0.nxs']
# work_30.0 ['python', '../scripts/reduce/reduceKeepingEvents.py', 'sim-30.0.nxs', '30.0', '100', '0,0.5,90', 'reduced_30.0.nxs']
# work_33.0 ['python', '../scripts/reduce/reduceKeepingEvents.py', 'sim-33.0.nxs', '33.0', '100', '0,0.5,90', 'reduced_33.0.nxs']
# work_36.0 ['python', '../scripts/reduce/reduceKeepingEvents.py', 'sim-36.0.nxs', '36.0', '100', '0,0.5,90', 'reduced_36.0.nxs']
# work_39.0 ['python', '../scripts/reduce/reduceKeepingEvents.py', 'sim-39.0.nxs', '39.0', '100', '0,0.5,90', 'reduced_39.0.nxs']
# work_42.0 ['python', '../scripts/reduce/reduceKeepingEvents.py', 'sim-42.0.nxs', '42.0', '100', '0,0.5,90', 'reduced_42.0.nxs']
# work_45.0 ['python', '../scripts/reduce/reduceKeepingEvents.py', 'sim-45.0.nxs', '45.0', '100', '0,0.5,90', 'reduced_45.0.nxs']
# work_48.0 ['python', '../scripts/reduce/reduceKeepingEvents.py', 'sim-48.0.nxs', '48.0', '100', '0,0.5,90', 'reduced_48.0.nxs']
# work_51.0 ['python', '../scripts/reduce/reduceKeepingEvents.py', 'sim-51.0.nxs', '51.0', '100', '0,0.5,90', 'reduced_51.0.nxs']
# work_54.0 ['python', '../scripts/reduce/reduceKeepingEvents.py', 'sim-54.0.nxs', '54.0', '100', '0,0.5,90', 'reduced_54.0.nxs']
# work_57.0 ['python', '../scripts/reduce/reduceKeepingEvents.py', 'sim-57.0.nxs', '57.0', '100', '0,0.5,90', 'reduced_57.0.nxs']
# work_60.0 ['python', '../scripts/reduce/reduceKeepingEvents.py', 'sim-60.0.nxs', '60.0', '100', '0,0.5,90', 'reduced_60.0.nxs']
# work_63.0 ['python', '../scripts/reduce/reduceKeepingEvents.py', 'sim-63.0.nxs', '63.0', '100', '0,0.5,90', 'reduced_63.0.nxs']
# work_66.0 ['python', '../scripts/reduce/reduceKeepingEvents.py', 'sim-66.0.nxs', '66.0', '100', '0,0.5,90', 'reduced_66.0.nxs']
# work_69.0 ['python', '../scripts/reduce/reduceKeepingEvents.py', 'sim-69.0.nxs', '69.0', '100', '0,0.5,90', 'reduced_69.0.nxs']
# work_72.0 ['python', '../scripts/reduce/reduceKeepingEvents.py', 'sim-72.0.nxs', '72.0', '100', '0,0.5,90', 'reduced_72.0.nxs']
# work_75.0 ['python', '../scripts/reduce/reduceKeepingEvents.py', 'sim-75.0.nxs', '75.0', '100', '0,0.5,90', 'reduced_75.0.nxs']
# work_78.0 ['python', '../scripts/reduce/reduceKeepingEvents.py', 'sim-78.0.nxs', '78.0', '100', '0,0.5,90', 'reduced_78.0.nxs']
# work_81.0 ['python', '../scripts/reduce/reduceKeepingEvents.py', 'sim-81.0.nxs', '81.0', '100', '0,0.5,90', 'reduced_81.0.nxs']
# work_84.0 ['python', '../scripts/reduce/reduceKeepingEvents.py', 'sim-84.0.nxs', '84.0', '100', '0,0.5,90', 'reduced_84.0.nxs']
# work_87.0 ['python', '../scripts/reduce/reduceKeepingEvents.py', 'sim-87.0.nxs', '87.0', '100', '0,0.5,90', 'reduced_87.0.nxs']
# work_90.0 ['python', '../scripts/reduce/reduceKeepingEvents.py', 'sim-90.0.nxs', '90.0', '100', '0,0.5,90', 'reduced_90.0.nxs']

# %%
# create configuration file for getting a slice

# %%
# %%file slice_H00.yml
#
# angles: -90,90.1,3.0
# filename_pattern: work_%(angle)s/reduced_%(angle)s.nxs
# lattice: 2., 2.5, 3., 90, 90, 90
# orientation:
#  u: 1, 0, 2
#  v: 1,0,0
# Eaxis:
#  min: 0
#  max: 90
#  N: 160
# Q_projections:
#  U:
#   proj: 1,0,0
#   proj_name: H,0,0
#   min: -5
#   max: 5
#   N: 251
#  V:
#   proj: 0,1,0
#   proj_name: 0,K,0
#   min: -1
#   max: 1
#   N: 1
#  W:
#   proj: 0,0,1
#   proj_name: 0,0,L
#   min: -1
#   max: 1
#   N: 1
# output: slice_H00.nxs
# Out:
# Overwriting slice_H00.yml

# %%
# hack for now. copy the config python file to current dir
# !cp /SNS/users/lj7/simulations/mcvine_workflow/DGS/ARCS/single-crystal/scripts/config.py .

# %%
# run script to calculate the slice
! PYTHONPATH=$PWD:$PYTHONPATH ./scripts/reduce/getaslice.py slice_H00.yml
# Out:
# -90.0 work_-90.0/reduced_-90.0.nxs
# FrameworkManager-[Notice] Welcome to Mantid 3.6.100
# FrameworkManager-[Notice] Please cite: http://dx.doi.org/10.1016/j.nima.2014.07.029 and this release: http://dx.doi.org/10.5286/Software/Mantid3.6.100
# Load-[Notice] Load started
# Load-[Notice] Load successful, Duration 58.98 seconds
# CompressEvents-[Notice] CompressEvents started
# CompressEvents-[Notice] CompressEvents started
# CompressEvents-[Notice] CompressEvents successful, Duration 0.60 seconds
# CompressEvents-[Notice] CompressEvents started
# CompressEvents-[Notice] CompressEvents successful, Duration 0.72 seconds
# CompressEvents-[Notice] CompressEvents started
# CompressEvents-[Notice] CompressEvents successful, Duration 0.76 seconds
# CompressEvents-[Notice] CompressEvents started
# CompressEvents-[Notice] CompressEvents successful, Duration 0.82 seconds
# CompressEvents-[Notice] CompressEvents started
# CompressEvents-[Notice] CompressEvents successful, Duration 1.45 seconds
# CompressEvents-[Notice] CompressEvents started
# CompressEvents-[Notice] CompressEvents successful, Duration 0.57 seconds
# CompressEvents-[Notice] CompressEvents started
# CompressEvents-[Notice] CompressEvents successful, Duration 0.54 seconds
# CompressEvents-[Notice] CompressEvents started
# CompressEvents-[Notice] CompressEvents successful, Duration 0.66 seconds
# CompressEvents-[Notice] CompressEvents started
# CompressEvents-[Notice] CompressEvents successful, Duration 0.84 seconds
# CompressEvents-[Notice] CompressEvents started
# CompressEvents-[Notice] CompressEvents successful, Duration 0.87 seconds
# CompressEvents-[Notice] CompressEvents started
# CompressEvents-[Notice] CompressEvents successful, Duration 0.84 seconds
# CompressEvents-[Notice] CompressEvents started
# CompressEvents-[Notice] CompressEvents successful, Duration 0.60 seconds
# CompressEvents-[Notice] CompressEvents started
# CompressEvents-[Notice] CompressEvents successful, Duration 0.99 seconds
# CompressEvents-[Notice] CompressEvents started
# CompressEvents-[Notice] CompressEvents successful, Duration 0.93 seconds
# CompressEvents-[Notice] CompressEvents started
# CompressEvents-[Notice] CompressEvents successful, Duration 1.06 seconds
# CompressEvents-[Notice] CompressEvents started
# CompressEvents-[Notice] CompressEvents successful, Duration 0.79 seconds
# CompressEvents-[Notice] CompressEvents started
# CompressEvents-[Notice] CompressEvents successful, Duration 0.72 seconds
# CompressEvents-[Notice] CompressEvents started
# CompressEvents-[Notice] CompressEvents successful, Duration 0.73 seconds
# CompressEvents-[Notice] CompressEvents started
# CompressEvents-[Notice] CompressEvents successful, Duration 0.67 seconds
# CompressEvents-[Notice] CompressEvents started
# CompressEvents-[Notice] CompressEvents successful, Duration 0.81 seconds
# CompressEvents-[Notice] CompressEvents started
# CompressEvents-[Notice] CompressEvents successful, Duration 0.84 seconds
# CompressEvents-[Notice] CompressEvents started
# CompressEvents-[Notice] CompressEvents successful, Duration 0.59 seconds
# CompressEvents-[Notice] CompressEvents started
# CompressEvents-[Notice] CompressEvents successful, Duration 0.91 seconds
# CompressEvents-[Notice] CompressEvents started
# CompressEvents-[Notice] CompressEvents successful, Duration 0.67 seconds
# CompressEvents-[Notice] CompressEvents started
# CompressEvents-[Notice] CompressEvents successful, Duration 0.61 seconds
# CompressEvents-[Notice] CompressEvents started
# CompressEvents-[Notice] CompressEvents successful, Duration 0.88 seconds
# CompressEvents-[Notice] CompressEvents started
# CompressEvents-[Notice] CompressEvents successful, Duration 0.73 seconds
# CompressEvents-[Notice] CompressEvents started
# CompressEvents-[Notice] CompressEvents successful, Duration 0.60 seconds
# CompressEvents-[Notice] CompressEvents started
# CompressEvents-[Notice] CompressEvents successful, Duration 0.95 seconds
# CompressEvents-[Notice] CompressEvents started
# CompressEvents-[Notice] CompressEvents successful, Duration 0.65 seconds
# CompressEvents-[Notice] CompressEvents started
# CompressEvents-[Notice] CompressEvents successful, Duration 0.70 seconds
# CompressEvents-[Notice] CompressEvents started
# CompressEvents-[Notice] CompressEvents successful, Duration 0.80 seconds
# CompressEvents-[Notice] CompressEvents started
# CompressEvents-[Notice] CompressEvents successful, Duration 0.58 seconds
# CompressEvents-[Notice] CompressEvents started
# CompressEvents-[Notice] CompressEvents successful, Duration 0.75 seconds
# CompressEvents-[Notice] CompressEvents started
# CompressEvents-[Notice] CompressEvents successful, Duration 0.59 seconds
# CompressEvents-[Notice] CompressEvents started
# CompressEvents-[Notice] CompressEvents successful, Duration 0.65 seconds
# CompressEvents-[Notice] CompressEvents started
# CompressEvents-[Notice] CompressEvents successful, Duration 0.65 seconds
# CompressEvents-[Notice] CompressEvents started
# CompressEvents-[Notice] CompressEvents successful, Duration 0.81 seconds
# CompressEvents-[Notice] CompressEvents started
# CompressEvents-[Notice] CompressEvents successful, Duration 0.65 seconds
# CompressEvents-[Notice] CompressEvents started
# CompressEvents-[Notice] CompressEvents successful, Duration 0.67 seconds
# CompressEvents-[Notice] CompressEvents started
# CompressEvents-[Notice] CompressEvents successful, Duration 0.67 seconds
# CompressEvents-[Notice] CompressEvents started
# CompressEvents-[Notice] CompressEvents successful, Duration 0.61 seconds
# CompressEvents-[Notice] CompressEvents started
# CompressEvents-[Notice] CompressEvents successful, Duration 0.74 seconds
# CompressEvents-[Notice] CompressEvents started
# CompressEvents-[Notice] CompressEvents successful, Duration 0.66 seconds
# CompressEvents-[Notice] CompressEvents started
# CompressEvents-[Notice] CompressEvents successful, Duration 0.62 seconds
# CompressEvents-[Notice] CompressEvents started
# CompressEvents-[Notice] CompressEvents successful, Duration 0.85 seconds
# CompressEvents-[Notice] CompressEvents started
# CompressEvents-[Notice] CompressEvents successful, Duration 0.61 seconds
# CompressEvents-[Notice] CompressEvents started
# CompressEvents-[Notice] CompressEvents successful, Duration 0.80 seconds
# CompressEvents-[Notice] CompressEvents started
# CompressEvents-[Notice] CompressEvents successful, Duration 0.70 seconds
# CompressEvents-[Notice] CompressEvents started
# CompressEvents-[Notice] CompressEvents successful, Duration 0.60 seconds
# CompressEvents-[Notice] CompressEvents started
# CompressEvents-[Notice] CompressEvents successful, Duration 0.70 seconds
# CompressEvents-[Notice] CompressEvents started
# CompressEvents-[Notice] CompressEvents successful, Duration 0.59 seconds
# CompressEvents-[Notice] CompressEvents started
# CompressEvents-[Notice] CompressEvents successful, Duration 0.59 seconds
# CompressEvents-[Notice] CompressEvents started
# CompressEvents-[Notice] CompressEvents successful, Duration 0.61 seconds
# CompressEvents-[Notice] CompressEvents started
# CompressEvents-[Notice] CompressEvents successful, Duration 0.61 seconds
# CompressEvents-[Notice] CompressEvents started
# CompressEvents-[Notice] CompressEvents successful, Duration 0.65 seconds
# CompressEvents-[Notice] CompressEvents started
# CompressEvents-[Notice] CompressEvents successful, Duration 0.70 seconds
# CompressEvents-[Notice] CompressEvents started
# CompressEvents-[Notice] CompressEvents successful, Duration 0.67 seconds
# CompressEvents-[Notice] CompressEvents started
# CompressEvents-[Notice] CompressEvents successful, Duration 0.59 seconds
# CompressEvents-[Notice] CompressEvents started
# CompressEvents-[Notice] CompressEvents successful, Duration 1.01 seconds
# CompressEvents-[Notice] CompressEvents started
# CompressEvents-[Notice] CompressEvents successful, Duration 0.62 seconds
# CompressEvents-[Notice] CompressEvents successful, Duration 44.50 seconds. Processed as a workspace group
# DeleteWorkspace-[Notice] DeleteWorkspace started
# DeleteWorkspace-[Notice] DeleteWorkspace started
# DeleteWorkspace-[Notice] DeleteWorkspace successful, Duration 0.00 seconds
# DeleteWorkspace-[Notice] DeleteWorkspace started
# DeleteWorkspace-[Notice] DeleteWorkspace successful, Duration 0.00 seconds
# DeleteWorkspace-[Notice] DeleteWorkspace started
# DeleteWorkspace-[Notice] DeleteWorkspace successful, Duration 0.00 seconds
# DeleteWorkspace-[Notice] DeleteWorkspace started
# DeleteWorkspace-[Notice] DeleteWorkspace successful, Duration 0.00 seconds
# DeleteWorkspace-[Notice] DeleteWorkspace started
# DeleteWorkspace-[Notice] DeleteWorkspace successful, Duration 0.00 seconds
# DeleteWorkspace-[Notice] DeleteWorkspace started
# DeleteWorkspace-[Notice] DeleteWorkspace successful, Duration 0.00 seconds
# DeleteWorkspace-[Notice] DeleteWorkspace started
# DeleteWorkspace-[Notice] DeleteWorkspace successful, Duration 0.00 seconds
# DeleteWorkspace-[Notice] DeleteWorkspace started
# DeleteWorkspace-[Notice] DeleteWorkspace successful, Duration 0.00 seconds
# DeleteWorkspace-[Notice] DeleteWorkspace started
# DeleteWorkspace-[Notice] DeleteWorkspace successful, Duration 0.00 seconds
# DeleteWorkspace-[Notice] DeleteWorkspace started
# DeleteWorkspace-[Notice] DeleteWorkspace successful, Duration 0.00 seconds
# DeleteWorkspace-[Notice] DeleteWorkspace started
# DeleteWorkspace-[Notice] DeleteWorkspace successful, Duration 0.00 seconds
# DeleteWorkspace-[Notice] DeleteWorkspace started
# DeleteWorkspace-[Notice] DeleteWorkspace successful, Duration 0.00 seconds
# DeleteWorkspace-[Notice] DeleteWorkspace started
# DeleteWorkspace-[Notice] DeleteWorkspace successful, Duration 0.00 seconds
# DeleteWorkspace-[Notice] DeleteWorkspace started
# DeleteWorkspace-[Notice] DeleteWorkspace successful, Duration 0.00 seconds
# DeleteWorkspace-[Notice] DeleteWorkspace started
# DeleteWorkspace-[Notice] DeleteWorkspace successful, Duration 0.00 seconds
# DeleteWorkspace-[Notice] DeleteWorkspace started
# DeleteWorkspace-[Notice] DeleteWorkspace successful, Duration 0.00 seconds
# DeleteWorkspace-[Notice] DeleteWorkspace started
# DeleteWorkspace-[Notice] DeleteWorkspace successful, Duration 0.00 seconds
# DeleteWorkspace-[Notice] DeleteWorkspace started
# DeleteWorkspace-[Notice] DeleteWorkspace successful, Duration 0.00 seconds
# DeleteWorkspace-[Notice] DeleteWorkspace started
# DeleteWorkspace-[Notice] DeleteWorkspace successful, Duration 0.00 seconds
# DeleteWorkspace-[Notice] DeleteWorkspace started
# DeleteWorkspace-[Notice] DeleteWorkspace successful, Duration 0.00 seconds
# DeleteWorkspace-[Notice] DeleteWorkspace started
# DeleteWorkspace-[Notice] DeleteWorkspace successful, Duration 0.00 seconds
# DeleteWorkspace-[Notice] DeleteWorkspace started
# DeleteWorkspace-[Notice] DeleteWorkspace successful, Duration 0.00 seconds
# DeleteWorkspace-[Notice] DeleteWorkspace started
# DeleteWorkspace-[Notice] DeleteWorkspace successful, Duration 0.00 seconds
# DeleteWorkspace-[Notice] DeleteWorkspace started
# DeleteWorkspace-[Notice] DeleteWorkspace successful, Duration 0.00 seconds
# DeleteWorkspace-[Notice] DeleteWorkspace started
# DeleteWorkspace-[Notice] DeleteWorkspace successful, Duration 0.00 seconds
# DeleteWorkspace-[Notice] DeleteWorkspace started
# DeleteWorkspace-[Notice] DeleteWorkspace successful, Duration 0.00 seconds
# DeleteWorkspace-[Notice] DeleteWorkspace started
# DeleteWorkspace-[Notice] DeleteWorkspace successful, Duration 0.00 seconds
# DeleteWorkspace-[Notice] DeleteWorkspace started
# DeleteWorkspace-[Notice] DeleteWorkspace successful, Duration 0.00 seconds
# DeleteWorkspace-[Notice] DeleteWorkspace started
# DeleteWorkspace-[Notice] DeleteWorkspace successful, Duration 0.00 seconds
# DeleteWorkspace-[Notice] DeleteWorkspace started
# DeleteWorkspace-[Notice] DeleteWorkspace successful, Duration 0.00 seconds
# DeleteWorkspace-[Notice] DeleteWorkspace started
# DeleteWorkspace-[Notice] DeleteWorkspace successful, Duration 0.00 seconds
# DeleteWorkspace-[Notice] DeleteWorkspace started
# DeleteWorkspace-[Notice] DeleteWorkspace successful, Duration 0.00 seconds
# DeleteWorkspace-[Notice] DeleteWorkspace started
# DeleteWorkspace-[Notice] DeleteWorkspace successful, Duration 0.00 seconds
# DeleteWorkspace-[Notice] DeleteWorkspace started
# DeleteWorkspace-[Notice] DeleteWorkspace successful, Duration 0.00 seconds
# DeleteWorkspace-[Notice] DeleteWorkspace started
# DeleteWorkspace-[Notice] DeleteWorkspace successful, Duration 0.00 seconds
# DeleteWorkspace-[Notice] DeleteWorkspace started
# DeleteWorkspace-[Notice] DeleteWorkspace successful, Duration 0.00 seconds
# DeleteWorkspace-[Notice] DeleteWorkspace started
# DeleteWorkspace-[Notice] DeleteWorkspace successful, Duration 0.00 seconds
# DeleteWorkspace-[Notice] DeleteWorkspace started
# DeleteWorkspace-[Notice] DeleteWorkspace successful, Duration 0.00 seconds
# DeleteWorkspace-[Notice] DeleteWorkspace started
# DeleteWorkspace-[Notice] DeleteWorkspace successful, Duration 0.00 seconds
# DeleteWorkspace-[Notice] DeleteWorkspace started
# DeleteWorkspace-[Notice] DeleteWorkspace successful, Duration 0.00 seconds
# DeleteWorkspace-[Notice] DeleteWorkspace started
# DeleteWorkspace-[Notice] DeleteWorkspace successful, Duration 0.00 seconds
# DeleteWorkspace-[Notice] DeleteWorkspace started
# DeleteWorkspace-[Notice] DeleteWorkspace successful, Duration 0.00 seconds
# DeleteWorkspace-[Notice] DeleteWorkspace started
# DeleteWorkspace-[Notice] DeleteWorkspace successful, Duration 0.00 seconds
# DeleteWorkspace-[Notice] DeleteWorkspace started
# DeleteWorkspace-[Notice] DeleteWorkspace successful, Duration 0.00 seconds
# DeleteWorkspace-[Notice] DeleteWorkspace started
# DeleteWorkspace-[Notice] DeleteWorkspace successful, Duration 0.00 seconds
# DeleteWorkspace-[Notice] DeleteWorkspace started
# DeleteWorkspace-[Notice] DeleteWorkspace successful, Duration 0.00 seconds
# DeleteWorkspace-[Notice] DeleteWorkspace started
# DeleteWorkspace-[Notice] DeleteWorkspace successful, Duration 0.00 seconds
# DeleteWorkspace-[Notice] DeleteWorkspace started
# DeleteWorkspace-[Notice] DeleteWorkspace successful, Duration 0.00 seconds
# DeleteWorkspace-[Notice] DeleteWorkspace started
# DeleteWorkspace-[Notice] DeleteWorkspace successful, Duration 0.00 seconds
# DeleteWorkspace-[Notice] DeleteWorkspace started
# DeleteWorkspace-[Notice] DeleteWorkspace successful, Duration 0.00 seconds
# DeleteWorkspace-[Notice] DeleteWorkspace started
# DeleteWorkspace-[Notice] DeleteWorkspace successful, Duration 0.00 seconds
# DeleteWorkspace-[Notice] DeleteWorkspace started
# DeleteWorkspace-[Notice] DeleteWorkspace successful, Duration 0.00 seconds
# DeleteWorkspace-[Notice] DeleteWorkspace started
# DeleteWorkspace-[Notice] DeleteWorkspace successful, Duration 0.00 seconds
# DeleteWorkspace-[Notice] DeleteWorkspace started
# DeleteWorkspace-[Notice] DeleteWorkspace successful, Duration 0.00 seconds
# DeleteWorkspace-[Notice] DeleteWorkspace started
# DeleteWorkspace-[Notice] DeleteWorkspace successful, Duration 0.00 seconds
# DeleteWorkspace-[Notice] DeleteWorkspace started
# DeleteWorkspace-[Notice] DeleteWorkspace successful, Duration 0.00 seconds
# DeleteWorkspace-[Notice] DeleteWorkspace started
# DeleteWorkspace-[Notice] DeleteWorkspace successful, Duration 0.00 seconds
# DeleteWorkspace-[Notice] DeleteWorkspace started
# DeleteWorkspace-[Notice] DeleteWorkspace successful, Duration 0.00 seconds
# DeleteWorkspace-[Notice] DeleteWorkspace started
# DeleteWorkspace-[Notice] DeleteWorkspace successful, Duration 0.00 seconds
# DeleteWorkspace-[Notice] DeleteWorkspace started
# DeleteWorkspace-[Notice] DeleteWorkspace successful, Duration 0.00 seconds
# DeleteWorkspace-[Notice] DeleteWorkspace started
# DeleteWorkspace-[Notice] DeleteWorkspace successful, Duration 0.00 seconds
# DeleteWorkspace-[Notice] DeleteWorkspace successful, Duration 0.02 seconds. Processed as a workspace group
# SetGoniometer-[Notice] SetGoniometer started
# SetGoniometer-[Notice] SetGoniometer started
# SetGoniometer-[Notice] SetGoniometer successful, Duration 0.00 seconds
# SetGoniometer-[Notice] SetGoniometer started
# SetGoniometer-[Notice] SetGoniometer successful, Duration 0.00 seconds
# SetGoniometer-[Notice] SetGoniometer started
# SetGoniometer-[Notice] SetGoniometer successful, Duration 0.00 seconds
# SetGoniometer-[Notice] SetGoniometer started
# SetGoniometer-[Notice] SetGoniometer successful, Duration 0.00 seconds
# SetGoniometer-[Notice] SetGoniometer started
# SetGoniometer-[Notice] SetGoniometer successful, Duration 0.00 seconds
# SetGoniometer-[Notice] SetGoniometer started
# SetGoniometer-[Notice] SetGoniometer successful, Duration 0.00 seconds
# SetGoniometer-[Notice] SetGoniometer started
# SetGoniometer-[Notice] SetGoniometer successful, Duration 0.00 seconds
# SetGoniometer-[Notice] SetGoniometer started
# SetGoniometer-[Notice] SetGoniometer successful, Duration 0.00 seconds
# SetGoniometer-[Notice] SetGoniometer started
# SetGoniometer-[Notice] SetGoniometer successful, Duration 0.00 seconds
# SetGoniometer-[Notice] SetGoniometer started
# SetGoniometer-[Notice] SetGoniometer successful, Duration 0.00 seconds
# SetGoniometer-[Notice] SetGoniometer started
# SetGoniometer-[Notice] SetGoniometer successful, Duration 0.00 seconds
# SetGoniometer-[Notice] SetGoniometer started
# SetGoniometer-[Notice] SetGoniometer successful, Duration 0.00 seconds
# SetGoniometer-[Notice] SetGoniometer started
# SetGoniometer-[Notice] SetGoniometer successful, Duration 0.00 seconds
# SetGoniometer-[Notice] SetGoniometer started
# SetGoniometer-[Notice] SetGoniometer successful, Duration 0.00 seconds
# SetGoniometer-[Notice] SetGoniometer started
# SetGoniometer-[Notice] SetGoniometer successful, Duration 0.00 seconds
# SetGoniometer-[Notice] SetGoniometer started
# SetGoniometer-[Notice] SetGoniometer successful, Duration 0.00 seconds
# SetGoniometer-[Notice] SetGoniometer started
# SetGoniometer-[Notice] SetGoniometer successful, Duration 0.00 seconds
# SetGoniometer-[Notice] SetGoniometer started
# SetGoniometer-[Notice] SetGoniometer successful, Duration 0.00 seconds
# SetGoniometer-[Notice] SetGoniometer started
# SetGoniometer-[Notice] SetGoniometer successful, Duration 0.00 seconds
# SetGoniometer-[Notice] SetGoniometer started
# SetGoniometer-[Notice] SetGoniometer successful, Duration 0.00 seconds
# SetGoniometer-[Notice] SetGoniometer started
# SetGoniometer-[Notice] SetGoniometer successful, Duration 0.00 seconds
# SetGoniometer-[Notice] SetGoniometer started
# SetGoniometer-[Notice] SetGoniometer successful, Duration 0.00 seconds
# SetGoniometer-[Notice] SetGoniometer started
# SetGoniometer-[Notice] SetGoniometer successful, Duration 0.00 seconds
# SetGoniometer-[Notice] SetGoniometer started
# SetGoniometer-[Notice] SetGoniometer successful, Duration 0.00 seconds
# SetGoniometer-[Notice] SetGoniometer started
# SetGoniometer-[Notice] SetGoniometer successful, Duration 0.00 seconds
# SetGoniometer-[Notice] SetGoniometer started
# SetGoniometer-[Notice] SetGoniometer successful, Duration 0.00 seconds
# SetGoniometer-[Notice] SetGoniometer started
# SetGoniometer-[Notice] SetGoniometer successful, Duration 0.00 seconds
# SetGoniometer-[Notice] SetGoniometer started
# SetGoniometer-[Notice] SetGoniometer successful, Duration 0.00 seconds
# SetGoniometer-[Notice] SetGoniometer started
# SetGoniometer-[Notice] SetGoniometer successful, Duration 0.00 seconds
# SetGoniometer-[Notice] SetGoniometer started
# SetGoniometer-[Notice] SetGoniometer successful, Duration 0.00 seconds
# SetGoniometer-[Notice] SetGoniometer started
# SetGoniometer-[Notice] SetGoniometer successful, Duration 0.00 seconds
# SetGoniometer-[Notice] SetGoniometer started
# SetGoniometer-[Notice] SetGoniometer successful, Duration 0.00 seconds
# SetGoniometer-[Notice] SetGoniometer started
# SetGoniometer-[Notice] SetGoniometer successful, Duration 0.00 seconds
# SetGoniometer-[Notice] SetGoniometer started
# SetGoniometer-[Notice] SetGoniometer successful, Duration 0.00 seconds
# SetGoniometer-[Notice] SetGoniometer started
# SetGoniometer-[Notice] SetGoniometer successful, Duration 0.00 seconds
# SetGoniometer-[Notice] SetGoniometer started
# SetGoniometer-[Notice] SetGoniometer successful, Duration 0.00 seconds
# SetGoniometer-[Notice] SetGoniometer started
# SetGoniometer-[Notice] SetGoniometer successful, Duration 0.00 seconds
# SetGoniometer-[Notice] SetGoniometer started
# SetGoniometer-[Notice] SetGoniometer successful, Duration 0.00 seconds
# SetGoniometer-[Notice] SetGoniometer started
# SetGoniometer-[Notice] SetGoniometer successful, Duration 0.00 seconds
# SetGoniometer-[Notice] SetGoniometer started
# SetGoniometer-[Notice] SetGoniometer successful, Duration 0.00 seconds
# SetGoniometer-[Notice] SetGoniometer started
# SetGoniometer-[Notice] SetGoniometer successful, Duration 0.00 seconds
# SetGoniometer-[Notice] SetGoniometer started
# SetGoniometer-[Notice] SetGoniometer successful, Duration 0.00 seconds
# SetGoniometer-[Notice] SetGoniometer started
# SetGoniometer-[Notice] SetGoniometer successful, Duration 0.00 seconds
# SetGoniometer-[Notice] SetGoniometer started
# SetGoniometer-[Notice] SetGoniometer successful, Duration 0.00 seconds
# SetGoniometer-[Notice] SetGoniometer started
# SetGoniometer-[Notice] SetGoniometer successful, Duration 0.00 seconds
# SetGoniometer-[Notice] SetGoniometer started
# SetGoniometer-[Notice] SetGoniometer successful, Duration 0.00 seconds
# SetGoniometer-[Notice] SetGoniometer started
# SetGoniometer-[Notice] SetGoniometer successful, Duration 0.00 seconds
# SetGoniometer-[Notice] SetGoniometer started
# SetGoniometer-[Notice] SetGoniometer successful, Duration 0.00 seconds
# SetGoniometer-[Notice] SetGoniometer started
# SetGoniometer-[Notice] SetGoniometer successful, Duration 0.00 seconds
# SetGoniometer-[Notice] SetGoniometer started
# SetGoniometer-[Notice] SetGoniometer successful, Duration 0.00 seconds
# SetGoniometer-[Notice] SetGoniometer started
# SetGoniometer-[Notice] SetGoniometer successful, Duration 0.00 seconds
# SetGoniometer-[Notice] SetGoniometer started
# SetGoniometer-[Notice] SetGoniometer successful, Duration 0.00 seconds
# SetGoniometer-[Notice] SetGoniometer started
# SetGoniometer-[Notice] SetGoniometer successful, Duration 0.00 seconds
# SetGoniometer-[Notice] SetGoniometer started
# SetGoniometer-[Notice] SetGoniometer successful, Duration 0.00 seconds
# SetGoniometer-[Notice] SetGoniometer started
# SetGoniometer-[Notice] SetGoniometer successful, Duration 0.00 seconds
# SetGoniometer-[Notice] SetGoniometer started
# SetGoniometer-[Notice] SetGoniometer successful, Duration 0.00 seconds
# SetGoniometer-[Notice] SetGoniometer started
# SetGoniometer-[Notice] SetGoniometer successful, Duration 0.00 seconds
# SetGoniometer-[Notice] SetGoniometer started
# SetGoniometer-[Notice] SetGoniometer successful, Duration 0.00 seconds
# SetGoniometer-[Notice] SetGoniometer started
# SetGoniometer-[Notice] SetGoniometer successful, Duration 0.00 seconds
# SetGoniometer-[Notice] SetGoniometer started
# SetGoniometer-[Notice] SetGoniometer successful, Duration 0.00 seconds
# SetGoniometer-[Notice] SetGoniometer started
# SetGoniometer-[Notice] SetGoniometer successful, Duration 0.00 seconds
# SetGoniometer-[Notice] SetGoniometer successful, Duration 0.02 seconds. Processed as a workspace group
# SetUB-[Notice] SetUB started
# SetUB-[Notice] SetUB started
# SetUB-[Notice] SetUB successful, Duration 0.00 seconds
# SetUB-[Notice] SetUB started
# SetUB-[Notice] SetUB successful, Duration 0.00 seconds
# SetUB-[Notice] SetUB started
# SetUB-[Notice] SetUB successful, Duration 0.00 seconds
# SetUB-[Notice] SetUB started
# SetUB-[Notice] SetUB successful, Duration 0.00 seconds
# SetUB-[Notice] SetUB started
# SetUB-[Notice] SetUB successful, Duration 0.00 seconds
# SetUB-[Notice] SetUB started
# SetUB-[Notice] SetUB successful, Duration 0.00 seconds
# SetUB-[Notice] SetUB started
# SetUB-[Notice] SetUB successful, Duration 0.00 seconds
# SetUB-[Notice] SetUB started
# SetUB-[Notice] SetUB successful, Duration 0.00 seconds
# SetUB-[Notice] SetUB started
# SetUB-[Notice] SetUB successful, Duration 0.00 seconds
# SetUB-[Notice] SetUB started
# SetUB-[Notice] SetUB successful, Duration 0.00 seconds
# SetUB-[Notice] SetUB started
# SetUB-[Notice] SetUB successful, Duration 0.00 seconds
# SetUB-[Notice] SetUB started
# SetUB-[Notice] SetUB successful, Duration 0.00 seconds
# SetUB-[Notice] SetUB started
# SetUB-[Notice] SetUB successful, Duration 0.00 seconds
# SetUB-[Notice] SetUB started
# SetUB-[Notice] SetUB successful, Duration 0.00 seconds
# SetUB-[Notice] SetUB started
# SetUB-[Notice] SetUB successful, Duration 0.00 seconds
# SetUB-[Notice] SetUB started
# SetUB-[Notice] SetUB successful, Duration 0.00 seconds
# SetUB-[Notice] SetUB started
# SetUB-[Notice] SetUB successful, Duration 0.00 seconds
# SetUB-[Notice] SetUB started
# SetUB-[Notice] SetUB successful, Duration 0.00 seconds
# SetUB-[Notice] SetUB started
# SetUB-[Notice] SetUB successful, Duration 0.00 seconds
# SetUB-[Notice] SetUB started
# SetUB-[Notice] SetUB successful, Duration 0.00 seconds
# SetUB-[Notice] SetUB started
# SetUB-[Notice] SetUB successful, Duration 0.00 seconds
# SetUB-[Notice] SetUB started
# SetUB-[Notice] SetUB successful, Duration 0.00 seconds
# SetUB-[Notice] SetUB started
# SetUB-[Notice] SetUB successful, Duration 0.00 seconds
# SetUB-[Notice] SetUB started
# SetUB-[Notice] SetUB successful, Duration 0.00 seconds
# SetUB-[Notice] SetUB started
# SetUB-[Notice] SetUB successful, Duration 0.00 seconds
# SetUB-[Notice] SetUB started
# SetUB-[Notice] SetUB successful, Duration 0.00 seconds
# SetUB-[Notice] SetUB started
# SetUB-[Notice] SetUB successful, Duration 0.00 seconds
# SetUB-[Notice] SetUB started
# SetUB-[Notice] SetUB successful, Duration 0.00 seconds
# SetUB-[Notice] SetUB started
# SetUB-[Notice] SetUB successful, Duration 0.00 seconds
# SetUB-[Notice] SetUB started
# SetUB-[Notice] SetUB successful, Duration 0.00 seconds
# SetUB-[Notice] SetUB started
# SetUB-[Notice] SetUB successful, Duration 0.00 seconds
# SetUB-[Notice] SetUB started
# SetUB-[Notice] SetUB successful, Duration 0.00 seconds
# SetUB-[Notice] SetUB started
# SetUB-[Notice] SetUB successful, Duration 0.00 seconds
# SetUB-[Notice] SetUB started
# SetUB-[Notice] SetUB successful, Duration 0.00 seconds
# SetUB-[Notice] SetUB started
# SetUB-[Notice] SetUB successful, Duration 0.00 seconds
# SetUB-[Notice] SetUB started
# SetUB-[Notice] SetUB successful, Duration 0.00 seconds
# SetUB-[Notice] SetUB started
# SetUB-[Notice] SetUB successful, Duration 0.00 seconds
# SetUB-[Notice] SetUB started
# SetUB-[Notice] SetUB successful, Duration 0.00 seconds
# SetUB-[Notice] SetUB started
# SetUB-[Notice] SetUB successful, Duration 0.00 seconds
# SetUB-[Notice] SetUB started
# SetUB-[Notice] SetUB successful, Duration 0.00 seconds
# SetUB-[Notice] SetUB started
# SetUB-[Notice] SetUB successful, Duration 0.00 seconds
# SetUB-[Notice] SetUB started
# SetUB-[Notice] SetUB successful, Duration 0.00 seconds
# SetUB-[Notice] SetUB started
# SetUB-[Notice] SetUB successful, Duration 0.00 seconds
# SetUB-[Notice] SetUB started
# SetUB-[Notice] SetUB successful, Duration 0.00 seconds
# SetUB-[Notice] SetUB started
# SetUB-[Notice] SetUB successful, Duration 0.00 seconds
# SetUB-[Notice] SetUB started
# SetUB-[Notice] SetUB successful, Duration 0.00 seconds
# SetUB-[Notice] SetUB started
# SetUB-[Notice] SetUB successful, Duration 0.00 seconds
# SetUB-[Notice] SetUB started
# SetUB-[Notice] SetUB successful, Duration 0.00 seconds
# SetUB-[Notice] SetUB started
# SetUB-[Notice] SetUB successful, Duration 0.00 seconds
# SetUB-[Notice] SetUB started
# SetUB-[Notice] SetUB successful, Duration 0.00 seconds
# SetUB-[Notice] SetUB started
# SetUB-[Notice] SetUB successful, Duration 0.00 seconds
# SetUB-[Notice] SetUB started
# SetUB-[Notice] SetUB successful, Duration 0.00 seconds
# SetUB-[Notice] SetUB started
# SetUB-[Notice] SetUB successful, Duration 0.00 seconds
# SetUB-[Notice] SetUB started
# SetUB-[Notice] SetUB successful, Duration 0.00 seconds
# SetUB-[Notice] SetUB started
# SetUB-[Notice] SetUB successful, Duration 0.00 seconds
# SetUB-[Notice] SetUB started
# SetUB-[Notice] SetUB successful, Duration 0.00 seconds
# SetUB-[Notice] SetUB started
# SetUB-[Notice] SetUB successful, Duration 0.00 seconds
# SetUB-[Notice] SetUB started
# SetUB-[Notice] SetUB successful, Duration 0.00 seconds
# SetUB-[Notice] SetUB started
# SetUB-[Notice] SetUB successful, Duration 0.00 seconds
# SetUB-[Notice] SetUB started
# SetUB-[Notice] SetUB successful, Duration 0.00 seconds
# SetUB-[Notice] SetUB started
# SetUB-[Notice] SetUB successful, Duration 0.00 seconds
# SetUB-[Notice] SetUB successful, Duration 0.03 seconds. Processed as a workspace group
# CropWorkspace-[Notice] CropWorkspace started
# CropWorkspace-[Notice] CropWorkspace started
# CropWorkspace-[Notice] CropWorkspace successful, Duration 0.49 seconds
# CropWorkspace-[Notice] CropWorkspace started
# CropWorkspace-[Notice] CropWorkspace successful, Duration 0.57 seconds
# CropWorkspace-[Notice] CropWorkspace started
# CropWorkspace-[Notice] CropWorkspace successful, Duration 0.59 seconds
# CropWorkspace-[Notice] CropWorkspace started
# CropWorkspace-[Notice] CropWorkspace successful, Duration 0.58 seconds
# CropWorkspace-[Notice] CropWorkspace started
# CropWorkspace-[Notice] CropWorkspace successful, Duration 0.54 seconds
# CropWorkspace-[Notice] CropWorkspace started
# CropWorkspace-[Notice] CropWorkspace successful, Duration 0.55 seconds
# CropWorkspace-[Notice] CropWorkspace started
# CropWorkspace-[Notice] CropWorkspace successful, Duration 0.94 seconds
# CropWorkspace-[Notice] CropWorkspace started
# CropWorkspace-[Notice] CropWorkspace successful, Duration 0.69 seconds
# CropWorkspace-[Notice] CropWorkspace started
# CropWorkspace-[Notice] CropWorkspace successful, Duration 0.93 seconds
# CropWorkspace-[Notice] CropWorkspace started
# CropWorkspace-[Notice] CropWorkspace successful, Duration 0.80 seconds
# CropWorkspace-[Notice] CropWorkspace started
# CropWorkspace-[Notice] CropWorkspace successful, Duration 0.67 seconds
# CropWorkspace-[Notice] CropWorkspace started
# CropWorkspace-[Notice] CropWorkspace successful, Duration 0.75 seconds
# CropWorkspace-[Notice] CropWorkspace started
# CropWorkspace-[Notice] CropWorkspace successful, Duration 0.69 seconds
# CropWorkspace-[Notice] CropWorkspace started
# CropWorkspace-[Notice] CropWorkspace successful, Duration 0.96 seconds
# CropWorkspace-[Notice] CropWorkspace started
# CropWorkspace-[Notice] CropWorkspace successful, Duration 0.74 seconds
# CropWorkspace-[Notice] CropWorkspace started
# CropWorkspace-[Notice] CropWorkspace successful, Duration 0.59 seconds
# CropWorkspace-[Notice] CropWorkspace started
# CropWorkspace-[Notice] CropWorkspace successful, Duration 0.57 seconds
# CropWorkspace-[Notice] CropWorkspace started
# CropWorkspace-[Notice] CropWorkspace successful, Duration 0.56 seconds
# CropWorkspace-[Notice] CropWorkspace started
# CropWorkspace-[Notice] CropWorkspace successful, Duration 0.66 seconds
# CropWorkspace-[Notice] CropWorkspace started
# CropWorkspace-[Notice] CropWorkspace successful, Duration 0.61 seconds
# CropWorkspace-[Notice] CropWorkspace started
# CropWorkspace-[Notice] CropWorkspace successful, Duration 0.90 seconds
# CropWorkspace-[Notice] CropWorkspace started
# CropWorkspace-[Notice] CropWorkspace successful, Duration 0.80 seconds
# CropWorkspace-[Notice] CropWorkspace started
# CropWorkspace-[Notice] CropWorkspace successful, Duration 0.65 seconds
# CropWorkspace-[Notice] CropWorkspace started
# CropWorkspace-[Notice] CropWorkspace successful, Duration 1.03 seconds
# CropWorkspace-[Notice] CropWorkspace started
# CropWorkspace-[Notice] CropWorkspace successful, Duration 0.88 seconds
# CropWorkspace-[Notice] CropWorkspace started
# CropWorkspace-[Notice] CropWorkspace successful, Duration 0.94 seconds
# CropWorkspace-[Notice] CropWorkspace started
# CropWorkspace-[Notice] CropWorkspace successful, Duration 0.69 seconds
# CropWorkspace-[Notice] CropWorkspace started
# CropWorkspace-[Notice] CropWorkspace successful, Duration 0.81 seconds
# CropWorkspace-[Notice] CropWorkspace started
# CropWorkspace-[Notice] CropWorkspace successful, Duration 1.04 seconds
# CropWorkspace-[Notice] CropWorkspace started
# CropWorkspace-[Notice] CropWorkspace successful, Duration 0.64 seconds
# CropWorkspace-[Notice] CropWorkspace started
# CropWorkspace-[Notice] CropWorkspace successful, Duration 0.67 seconds
# CropWorkspace-[Notice] CropWorkspace started
# CropWorkspace-[Notice] CropWorkspace successful, Duration 0.70 seconds
# CropWorkspace-[Notice] CropWorkspace started
# CropWorkspace-[Notice] CropWorkspace successful, Duration 0.94 seconds
# CropWorkspace-[Notice] CropWorkspace started
# CropWorkspace-[Notice] CropWorkspace successful, Duration 1.06 seconds
# CropWorkspace-[Notice] CropWorkspace started
# CropWorkspace-[Notice] CropWorkspace successful, Duration 0.66 seconds
# CropWorkspace-[Notice] CropWorkspace started
# CropWorkspace-[Notice] CropWorkspace successful, Duration 0.64 seconds
# CropWorkspace-[Notice] CropWorkspace started
# CropWorkspace-[Notice] CropWorkspace successful, Duration 0.92 seconds
# CropWorkspace-[Notice] CropWorkspace started
# CropWorkspace-[Notice] CropWorkspace successful, Duration 1.20 seconds
# CropWorkspace-[Notice] CropWorkspace started
# CropWorkspace-[Notice] CropWorkspace successful, Duration 1.04 seconds
# CropWorkspace-[Notice] CropWorkspace started
# CropWorkspace-[Notice] CropWorkspace successful, Duration 0.66 seconds
# CropWorkspace-[Notice] CropWorkspace started
# CropWorkspace-[Notice] CropWorkspace successful, Duration 0.90 seconds
# CropWorkspace-[Notice] CropWorkspace started
# CropWorkspace-[Notice] CropWorkspace successful, Duration 0.62 seconds
# CropWorkspace-[Notice] CropWorkspace started
# CropWorkspace-[Notice] CropWorkspace successful, Duration 0.61 seconds
# CropWorkspace-[Notice] CropWorkspace started
# CropWorkspace-[Notice] CropWorkspace successful, Duration 0.64 seconds
# CropWorkspace-[Notice] CropWorkspace started
# CropWorkspace-[Notice] CropWorkspace successful, Duration 0.92 seconds
# CropWorkspace-[Notice] CropWorkspace started
# CropWorkspace-[Notice] CropWorkspace successful, Duration 0.93 seconds
# CropWorkspace-[Notice] CropWorkspace started
# CropWorkspace-[Notice] CropWorkspace successful, Duration 0.73 seconds
# CropWorkspace-[Notice] CropWorkspace started
# CropWorkspace-[Notice] CropWorkspace successful, Duration 0.86 seconds
# CropWorkspace-[Notice] CropWorkspace started
# CropWorkspace-[Notice] CropWorkspace successful, Duration 1.06 seconds
# CropWorkspace-[Notice] CropWorkspace started
# CropWorkspace-[Notice] CropWorkspace successful, Duration 0.86 seconds
# CropWorkspace-[Notice] CropWorkspace started
# CropWorkspace-[Notice] CropWorkspace successful, Duration 0.62 seconds
# CropWorkspace-[Notice] CropWorkspace started
# CropWorkspace-[Notice] CropWorkspace successful, Duration 0.91 seconds
# CropWorkspace-[Notice] CropWorkspace started
# CropWorkspace-[Notice] CropWorkspace successful, Duration 0.95 seconds
# CropWorkspace-[Notice] CropWorkspace started
# CropWorkspace-[Notice] CropWorkspace successful, Duration 0.98 seconds
# CropWorkspace-[Notice] CropWorkspace started
# CropWorkspace-[Notice] CropWorkspace successful, Duration 0.65 seconds
# CropWorkspace-[Notice] CropWorkspace started
# CropWorkspace-[Notice] CropWorkspace successful, Duration 0.87 seconds
# CropWorkspace-[Notice] CropWorkspace started
# CropWorkspace-[Notice] CropWorkspace successful, Duration 0.63 seconds
# CropWorkspace-[Notice] CropWorkspace started
# CropWorkspace-[Notice] CropWorkspace successful, Duration 1.09 seconds
# CropWorkspace-[Notice] CropWorkspace started
# CropWorkspace-[Notice] CropWorkspace successful, Duration 0.58 seconds
# CropWorkspace-[Notice] CropWorkspace started
# CropWorkspace-[Notice] CropWorkspace successful, Duration 0.62 seconds
# CropWorkspace-[Notice] CropWorkspace started
# CropWorkspace-[Notice] CropWorkspace successful, Duration 0.94 seconds
# CropWorkspace-[Notice] CropWorkspace successful, Duration 47.79 seconds. Processed as a workspace group
# DeleteWorkspace-[Notice] DeleteWorkspace started
# DeleteWorkspace-[Notice] DeleteWorkspace started
# DeleteWorkspace-[Notice] DeleteWorkspace successful, Duration 0.00 seconds
# DeleteWorkspace-[Notice] DeleteWorkspace started
# DeleteWorkspace-[Notice] DeleteWorkspace successful, Duration 0.00 seconds
# DeleteWorkspace-[Notice] DeleteWorkspace started
# DeleteWorkspace-[Notice] DeleteWorkspace successful, Duration 0.00 seconds
# DeleteWorkspace-[Notice] DeleteWorkspace started
# DeleteWorkspace-[Notice] DeleteWorkspace successful, Duration 0.00 seconds
# DeleteWorkspace-[Notice] DeleteWorkspace started
# DeleteWorkspace-[Notice] DeleteWorkspace successful, Duration 0.00 seconds
# DeleteWorkspace-[Notice] DeleteWorkspace started
# DeleteWorkspace-[Notice] DeleteWorkspace successful, Duration 0.00 seconds
# DeleteWorkspace-[Notice] DeleteWorkspace started
# DeleteWorkspace-[Notice] DeleteWorkspace successful, Duration 0.00 seconds
# DeleteWorkspace-[Notice] DeleteWorkspace started
# DeleteWorkspace-[Notice] DeleteWorkspace successful, Duration 0.00 seconds
# DeleteWorkspace-[Notice] DeleteWorkspace started
# DeleteWorkspace-[Notice] DeleteWorkspace successful, Duration 0.00 seconds
# DeleteWorkspace-[Notice] DeleteWorkspace started
# DeleteWorkspace-[Notice] DeleteWorkspace successful, Duration 0.00 seconds
# DeleteWorkspace-[Notice] DeleteWorkspace started
# DeleteWorkspace-[Notice] DeleteWorkspace successful, Duration 0.00 seconds
# DeleteWorkspace-[Notice] DeleteWorkspace started
# DeleteWorkspace-[Notice] DeleteWorkspace successful, Duration 0.00 seconds
# DeleteWorkspace-[Notice] DeleteWorkspace started
# DeleteWorkspace-[Notice] DeleteWorkspace successful, Duration 0.00 seconds
# DeleteWorkspace-[Notice] DeleteWorkspace started
# DeleteWorkspace-[Notice] DeleteWorkspace successful, Duration 0.00 seconds
# DeleteWorkspace-[Notice] DeleteWorkspace started
# DeleteWorkspace-[Notice] DeleteWorkspace successful, Duration 0.00 seconds
# DeleteWorkspace-[Notice] DeleteWorkspace started
# DeleteWorkspace-[Notice] DeleteWorkspace successful, Duration 0.00 seconds
# DeleteWorkspace-[Notice] DeleteWorkspace started
# DeleteWorkspace-[Notice] DeleteWorkspace successful, Duration 0.00 seconds
# DeleteWorkspace-[Notice] DeleteWorkspace started
# DeleteWorkspace-[Notice] DeleteWorkspace successful, Duration 0.00 seconds
# DeleteWorkspace-[Notice] DeleteWorkspace started
# DeleteWorkspace-[Notice] DeleteWorkspace successful, Duration 0.00 seconds
# DeleteWorkspace-[Notice] DeleteWorkspace started
# DeleteWorkspace-[Notice] DeleteWorkspace successful, Duration 0.00 seconds
# DeleteWorkspace-[Notice] DeleteWorkspace started
# DeleteWorkspace-[Notice] DeleteWorkspace successful, Duration 0.00 seconds
# DeleteWorkspace-[Notice] DeleteWorkspace started
# DeleteWorkspace-[Notice] DeleteWorkspace successful, Duration 0.00 seconds
# DeleteWorkspace-[Notice] DeleteWorkspace started
# DeleteWorkspace-[Notice] DeleteWorkspace successful, Duration 0.00 seconds
# DeleteWorkspace-[Notice] DeleteWorkspace started
# DeleteWorkspace-[Notice] DeleteWorkspace successful, Duration 0.00 seconds
# DeleteWorkspace-[Notice] DeleteWorkspace started
# DeleteWorkspace-[Notice] DeleteWorkspace successful, Duration 0.00 seconds
# DeleteWorkspace-[Notice] DeleteWorkspace started
# DeleteWorkspace-[Notice] DeleteWorkspace successful, Duration 0.00 seconds
# DeleteWorkspace-[Notice] DeleteWorkspace started
# DeleteWorkspace-[Notice] DeleteWorkspace successful, Duration 0.00 seconds
# DeleteWorkspace-[Notice] DeleteWorkspace started
# DeleteWorkspace-[Notice] DeleteWorkspace successful, Duration 0.00 seconds
# DeleteWorkspace-[Notice] DeleteWorkspace started
# DeleteWorkspace-[Notice] DeleteWorkspace successful, Duration 0.00 seconds
# DeleteWorkspace-[Notice] DeleteWorkspace started
# DeleteWorkspace-[Notice] DeleteWorkspace successful, Duration 0.00 seconds
# DeleteWorkspace-[Notice] DeleteWorkspace started
# DeleteWorkspace-[Notice] DeleteWorkspace successful, Duration 0.00 seconds
# DeleteWorkspace-[Notice] DeleteWorkspace started
# DeleteWorkspace-[Notice] DeleteWorkspace successful, Duration 0.00 seconds
# DeleteWorkspace-[Notice] DeleteWorkspace started
# DeleteWorkspace-[Notice] DeleteWorkspace successful, Duration 0.00 seconds
# DeleteWorkspace-[Notice] DeleteWorkspace started
# DeleteWorkspace-[Notice] DeleteWorkspace successful, Duration 0.00 seconds
# DeleteWorkspace-[Notice] DeleteWorkspace started
# DeleteWorkspace-[Notice] DeleteWorkspace successful, Duration 0.00 seconds
# DeleteWorkspace-[Notice] DeleteWorkspace started
# DeleteWorkspace-[Notice] DeleteWorkspace successful, Duration 0.00 seconds
# DeleteWorkspace-[Notice] DeleteWorkspace started
# DeleteWorkspace-[Notice] DeleteWorkspace successful, Duration 0.00 seconds
# DeleteWorkspace-[Notice] DeleteWorkspace started
# DeleteWorkspace-[Notice] DeleteWorkspace successful, Duration 0.00 seconds
# DeleteWorkspace-[Notice] DeleteWorkspace started
# DeleteWorkspace-[Notice] DeleteWorkspace successful, Duration 0.00 seconds
# DeleteWorkspace-[Notice] DeleteWorkspace started
# DeleteWorkspace-[Notice] DeleteWorkspace successful, Duration 0.00 seconds
# DeleteWorkspace-[Notice] DeleteWorkspace started
# DeleteWorkspace-[Notice] DeleteWorkspace successful, Duration 0.00 seconds
# DeleteWorkspace-[Notice] DeleteWorkspace started
# DeleteWorkspace-[Notice] DeleteWorkspace successful, Duration 0.00 seconds
# DeleteWorkspace-[Notice] DeleteWorkspace started
# DeleteWorkspace-[Notice] DeleteWorkspace successful, Duration 0.00 seconds
# DeleteWorkspace-[Notice] DeleteWorkspace started
# DeleteWorkspace-[Notice] DeleteWorkspace successful, Duration 0.00 seconds
# DeleteWorkspace-[Notice] DeleteWorkspace started
# DeleteWorkspace-[Notice] DeleteWorkspace successful, Duration 0.00 seconds
# DeleteWorkspace-[Notice] DeleteWorkspace started
# DeleteWorkspace-[Notice] DeleteWorkspace successful, Duration 0.00 seconds
# DeleteWorkspace-[Notice] DeleteWorkspace started
# DeleteWorkspace-[Notice] DeleteWorkspace successful, Duration 0.00 seconds
# DeleteWorkspace-[Notice] DeleteWorkspace started
# DeleteWorkspace-[Notice] DeleteWorkspace successful, Duration 0.00 seconds
# DeleteWorkspace-[Notice] DeleteWorkspace started
# DeleteWorkspace-[Notice] DeleteWorkspace successful, Duration 0.00 seconds
# DeleteWorkspace-[Notice] DeleteWorkspace started
# DeleteWorkspace-[Notice] DeleteWorkspace successful, Duration 0.00 seconds
# DeleteWorkspace-[Notice] DeleteWorkspace started
# DeleteWorkspace-[Notice] DeleteWorkspace successful, Duration 0.00 seconds
# DeleteWorkspace-[Notice] DeleteWorkspace started
# DeleteWorkspace-[Notice] DeleteWorkspace successful, Duration 0.00 seconds
# DeleteWorkspace-[Notice] DeleteWorkspace started
# DeleteWorkspace-[Notice] DeleteWorkspace successful, Duration 0.00 seconds
# DeleteWorkspace-[Notice] DeleteWorkspace started
# DeleteWorkspace-[Notice] DeleteWorkspace successful, Duration 0.00 seconds
# DeleteWorkspace-[Notice] DeleteWorkspace started
# DeleteWorkspace-[Notice] DeleteWorkspace successful, Duration 0.00 seconds
# DeleteWorkspace-[Notice] DeleteWorkspace started
# DeleteWorkspace-[Notice] DeleteWorkspace successful, Duration 0.00 seconds
# DeleteWorkspace-[Notice] DeleteWorkspace started
# DeleteWorkspace-[Notice] DeleteWorkspace successful, Duration 0.00 seconds
# DeleteWorkspace-[Notice] DeleteWorkspace started
# DeleteWorkspace-[Notice] DeleteWorkspace successful, Duration 0.00 seconds
# DeleteWorkspace-[Notice] DeleteWorkspace started
# DeleteWorkspace-[Notice] DeleteWorkspace successful, Duration 0.00 seconds
# DeleteWorkspace-[Notice] DeleteWorkspace started
# DeleteWorkspace-[Notice] DeleteWorkspace successful, Duration 0.00 seconds
# DeleteWorkspace-[Notice] DeleteWorkspace started
# DeleteWorkspace-[Notice] DeleteWorkspace successful, Duration 0.00 seconds
# DeleteWorkspace-[Notice] DeleteWorkspace successful, Duration 0.02 seconds. Processed as a workspace group
# ConvertToMD-[Notice] ConvertToMD started
# ConvertToMD-[Notice] ConvertToMD successful, Duration 2.29 seconds
# {'AlignedDim1': 'DeltaE,0,80, 160', 'AlignedDim0': '[H,0,0],-5,5,251', 'AlignedDim3': '[0,0,L],-1,1,1', 'AlignedDim2': '[0,K,0],-1,1,1'}
# MDNormDirectSC-[Notice] MDNormDirectSC started
# MDNormDirectSC-[Notice] MDNormDirectSC successful, Duration 14.92 seconds
# rotation angle #0: -90.0
# CloneMDWorkspace-[Notice] CloneMDWorkspace started
# CloneMDWorkspace-[Notice] CloneMDWorkspace successful, Duration 0.00 seconds
# CloneMDWorkspace-[Notice] CloneMDWorkspace started
# CloneMDWorkspace-[Notice] CloneMDWorkspace successful, Duration 0.00 seconds
# ConvertToMD-[Notice] ConvertToMD started
# ConvertToMD-[Notice] ConvertToMD successful, Duration 0.28 seconds
# {'AlignedDim1': 'DeltaE,0,80, 160', 'AlignedDim0': '[H,0,0],-5,5,251', 'AlignedDim3': '[0,0,L],-1,1,1', 'AlignedDim2': '[0,K,0],-1,1,1'}
# MDNormDirectSC-[Notice] MDNormDirectSC started
# MDNormDirectSC-[Notice] MDNormDirectSC successful, Duration 15.90 seconds
# rotation angle #1: -87.0
# PlusMD-[Notice] PlusMD started
# PlusMD-[Notice] PlusMD successful, Duration 0.00 seconds
# PlusMD-[Notice] PlusMD started
# PlusMD-[Notice] PlusMD successful, Duration 0.01 seconds
# ConvertToMD-[Notice] ConvertToMD started
# ConvertToMD-[Notice] ConvertToMD successful, Duration 0.33 seconds
# {'AlignedDim1': 'DeltaE,0,80, 160', 'AlignedDim0': '[H,0,0],-5,5,251', 'AlignedDim3': '[0,0,L],-1,1,1', 'AlignedDim2': '[0,K,0],-1,1,1'}
# MDNormDirectSC-[Notice] MDNormDirectSC started
# MDNormDirectSC-[Notice] MDNormDirectSC successful, Duration 16.28 seconds
# rotation angle #2: -84.0
# PlusMD-[Notice] PlusMD started
# PlusMD-[Notice] PlusMD successful, Duration 0.00 seconds
# PlusMD-[Notice] PlusMD started
# PlusMD-[Notice] PlusMD successful, Duration 0.00 seconds
# ConvertToMD-[Notice] ConvertToMD started
# ConvertToMD-[Notice] ConvertToMD successful, Duration 0.24 seconds
# {'AlignedDim1': 'DeltaE,0,80, 160', 'AlignedDim0': '[H,0,0],-5,5,251', 'AlignedDim3': '[0,0,L],-1,1,1', 'AlignedDim2': '[0,K,0],-1,1,1'}
# MDNormDirectSC-[Notice] MDNormDirectSC started
# MDNormDirectSC-[Notice] MDNormDirectSC successful, Duration 16.52 seconds
# rotation angle #3: -81.0
# PlusMD-[Notice] PlusMD started
# PlusMD-[Notice] PlusMD successful, Duration 0.01 seconds
# PlusMD-[Notice] PlusMD started
# PlusMD-[Notice] PlusMD successful, Duration 0.00 seconds
# ConvertToMD-[Notice] ConvertToMD started
# ConvertToMD-[Notice] ConvertToMD successful, Duration 0.30 seconds
# {'AlignedDim1': 'DeltaE,0,80, 160', 'AlignedDim0': '[H,0,0],-5,5,251', 'AlignedDim3': '[0,0,L],-1,1,1', 'AlignedDim2': '[0,K,0],-1,1,1'}
# MDNormDirectSC-[Notice] MDNormDirectSC started
# MDNormDirectSC-[Notice] MDNormDirectSC successful, Duration 16.12 seconds
# rotation angle #4: -78.0
# PlusMD-[Notice] PlusMD started
# PlusMD-[Notice] PlusMD successful, Duration 0.00 seconds
# PlusMD-[Notice] PlusMD started
# PlusMD-[Notice] PlusMD successful, Duration 0.00 seconds
# ConvertToMD-[Notice] ConvertToMD started
# ConvertToMD-[Notice] ConvertToMD successful, Duration 0.37 seconds
# {'AlignedDim1': 'DeltaE,0,80, 160', 'AlignedDim0': '[H,0,0],-5,5,251', 'AlignedDim3': '[0,0,L],-1,1,1', 'AlignedDim2': '[0,K,0],-1,1,1'}
# MDNormDirectSC-[Notice] MDNormDirectSC started
# MDNormDirectSC-[Notice] MDNormDirectSC successful, Duration 14.98 seconds
# rotation angle #5: -75.0
# PlusMD-[Notice] PlusMD started
# PlusMD-[Notice] PlusMD successful, Duration 0.00 seconds
# PlusMD-[Notice] PlusMD started
# PlusMD-[Notice] PlusMD successful, Duration 0.00 seconds
# ConvertToMD-[Notice] ConvertToMD started
# ConvertToMD-[Notice] ConvertToMD successful, Duration 0.38 seconds
# {'AlignedDim1': 'DeltaE,0,80, 160', 'AlignedDim0': '[H,0,0],-5,5,251', 'AlignedDim3': '[0,0,L],-1,1,1', 'AlignedDim2': '[0,K,0],-1,1,1'}
# MDNormDirectSC-[Notice] MDNormDirectSC started
# MDNormDirectSC-[Notice] MDNormDirectSC successful, Duration 13.57 seconds
# rotation angle #6: -72.0
# PlusMD-[Notice] PlusMD started
# PlusMD-[Notice] PlusMD successful, Duration 0.00 seconds
# PlusMD-[Notice] PlusMD started
# PlusMD-[Notice] PlusMD successful, Duration 0.00 seconds
# ConvertToMD-[Notice] ConvertToMD started
# ConvertToMD-[Notice] ConvertToMD successful, Duration 0.43 seconds
# {'AlignedDim1': 'DeltaE,0,80, 160', 'AlignedDim0': '[H,0,0],-5,5,251', 'AlignedDim3': '[0,0,L],-1,1,1', 'AlignedDim2': '[0,K,0],-1,1,1'}
# MDNormDirectSC-[Notice] MDNormDirectSC started
# MDNormDirectSC-[Notice] MDNormDirectSC successful, Duration 12.25 seconds
# rotation angle #7: -69.0
# PlusMD-[Notice] PlusMD started
# PlusMD-[Notice] PlusMD successful, Duration 0.00 seconds
# PlusMD-[Notice] PlusMD started
# PlusMD-[Notice] PlusMD successful, Duration 0.00 seconds
# ConvertToMD-[Notice] ConvertToMD started
# ConvertToMD-[Notice] ConvertToMD successful, Duration 0.41 seconds
# {'AlignedDim1': 'DeltaE,0,80, 160', 'AlignedDim0': '[H,0,0],-5,5,251', 'AlignedDim3': '[0,0,L],-1,1,1', 'AlignedDim2': '[0,K,0],-1,1,1'}
# MDNormDirectSC-[Notice] MDNormDirectSC started
# MDNormDirectSC-[Notice] MDNormDirectSC successful, Duration 10.90 seconds
# rotation angle #8: -66.0
# PlusMD-[Notice] PlusMD started
# ...
# ConvertToMD-[Notice] ConvertToMD started
# ConvertToMD-[Notice] ConvertToMD successful, Duration 0.28 seconds
# {'AlignedDim1': 'DeltaE,0,80, 160', 'AlignedDim0': '[H,0,0],-5,5,251', 'AlignedDim3': '[0,0,L],-1,1,1', 'AlignedDim2': '[0,K,0],-1,1,1'}
# MDNormDirectSC-[Notice] MDNormDirectSC started
# MDNormDirectSC-[Notice] MDNormDirectSC successful, Duration 3.52 seconds
# rotation angle #34: 12.0
# PlusMD-[Notice] PlusMD started
# PlusMD-[Notice] PlusMD successful, Duration 0.00 seconds
# PlusMD-[Notice] PlusMD started
# PlusMD-[Notice] PlusMD successful, Duration 0.00 seconds
# ConvertToMD-[Notice] ConvertToMD started
# ConvertToMD-[Notice] ConvertToMD successful, Duration 0.26 seconds
# {'AlignedDim1': 'DeltaE,0,80, 160', 'AlignedDim0': '[H,0,0],-5,5,251', 'AlignedDim3': '[0,0,L],-1,1,1', 'AlignedDim2': '[0,K,0],-1,1,1'}
# MDNormDirectSC-[Notice] MDNormDirectSC started
# MDNormDirectSC-[Notice] MDNormDirectSC successful, Duration 3.41 seconds
# rotation angle #35: 15.0
# PlusMD-[Notice] PlusMD started
# PlusMD-[Notice] PlusMD successful, Duration 0.00 seconds
# PlusMD-[Notice] PlusMD started
# PlusMD-[Notice] PlusMD successful, Duration 0.00 seconds
# ConvertToMD-[Notice] ConvertToMD started
# ConvertToMD-[Notice] ConvertToMD successful, Duration 0.23 seconds
# {'AlignedDim1': 'DeltaE,0,80, 160', 'AlignedDim0': '[H,0,0],-5,5,251', 'AlignedDim3': '[0,0,L],-1,1,1', 'AlignedDim2': '[0,K,0],-1,1,1'}
# MDNormDirectSC-[Notice] MDNormDirectSC started
# MDNormDirectSC-[Notice] MDNormDirectSC successful, Duration 3.45 seconds
# rotation angle #36: 18.0
# PlusMD-[Notice] PlusMD started
# PlusMD-[Notice] PlusMD successful, Duration 0.00 seconds
# PlusMD-[Notice] PlusMD started
# PlusMD-[Notice] PlusMD successful, Duration 0.00 seconds
# ConvertToMD-[Notice] ConvertToMD started
# ConvertToMD-[Notice] ConvertToMD successful, Duration 0.26 seconds
# {'AlignedDim1': 'DeltaE,0,80, 160', 'AlignedDim0': '[H,0,0],-5,5,251', 'AlignedDim3': '[0,0,L],-1,1,1', 'AlignedDim2': '[0,K,0],-1,1,1'}
# MDNormDirectSC-[Notice] MDNormDirectSC started
# MDNormDirectSC-[Notice] MDNormDirectSC successful, Duration 3.47 seconds
# rotation angle #37: 21.0
# PlusMD-[Notice] PlusMD started
# PlusMD-[Notice] PlusMD successful, Duration 0.00 seconds
# PlusMD-[Notice] PlusMD started
# PlusMD-[Notice] PlusMD successful, Duration 0.00 seconds
# ConvertToMD-[Notice] ConvertToMD started
# ConvertToMD-[Notice] ConvertToMD successful, Duration 0.25 seconds
# {'AlignedDim1': 'DeltaE,0,80, 160', 'AlignedDim0': '[H,0,0],-5,5,251', 'AlignedDim3': '[0,0,L],-1,1,1', 'AlignedDim2': '[0,K,0],-1,1,1'}
# MDNormDirectSC-[Notice] MDNormDirectSC started
# MDNormDirectSC-[Notice] MDNormDirectSC successful, Duration 3.41 seconds
# rotation angle #38: 24.0
# PlusMD-[Notice] PlusMD started
# PlusMD-[Notice] PlusMD successful, Duration 0.00 seconds
# PlusMD-[Notice] PlusMD started
# PlusMD-[Notice] PlusMD successful, Duration 0.00 seconds
# ConvertToMD-[Notice] ConvertToMD started
# ConvertToMD-[Notice] ConvertToMD successful, Duration 0.24 seconds
# {'AlignedDim1': 'DeltaE,0,80, 160', 'AlignedDim0': '[H,0,0],-5,5,251', 'AlignedDim3': '[0,0,L],-1,1,1', 'AlignedDim2': '[0,K,0],-1,1,1'}
# MDNormDirectSC-[Notice] MDNormDirectSC started
# MDNormDirectSC-[Notice] MDNormDirectSC successful, Duration 3.43 seconds
# rotation angle #39: 27.0
# PlusMD-[Notice] PlusMD started
# PlusMD-[Notice] PlusMD successful, Duration 0.00 seconds
# PlusMD-[Notice] PlusMD started
# PlusMD-[Notice] PlusMD successful, Duration 0.00 seconds
# ConvertToMD-[Notice] ConvertToMD started
# ConvertToMD-[Notice] ConvertToMD successful, Duration 0.22 seconds
# {'AlignedDim1': 'DeltaE,0,80, 160', 'AlignedDim0': '[H,0,0],-5,5,251', 'AlignedDim3': '[0,0,L],-1,1,1', 'AlignedDim2': '[0,K,0],-1,1,1'}
# MDNormDirectSC-[Notice] MDNormDirectSC started
# MDNormDirectSC-[Notice] MDNormDirectSC successful, Duration 3.47 seconds
# rotation angle #40: 30.0
# PlusMD-[Notice] PlusMD started
# PlusMD-[Notice] PlusMD successful, Duration 0.00 seconds
# PlusMD-[Notice] PlusMD started
# PlusMD-[Notice] PlusMD successful, Duration 0.00 seconds
# ConvertToMD-[Notice] ConvertToMD started
# ConvertToMD-[Notice] ConvertToMD successful, Duration 0.26 seconds
# {'AlignedDim1': 'DeltaE,0,80, 160', 'AlignedDim0': '[H,0,0],-5,5,251', 'AlignedDim3': '[0,0,L],-1,1,1', 'AlignedDim2': '[0,K,0],-1,1,1'}
# MDNormDirectSC-[Notice] MDNormDirectSC started
# MDNormDirectSC-[Notice] MDNormDirectSC successful, Duration 3.46 seconds
# rotation angle #41: 33.0
# PlusMD-[Notice] PlusMD started
# PlusMD-[Notice] PlusMD successful, Duration 0.00 seconds
# PlusMD-[Notice] PlusMD started
# PlusMD-[Notice] PlusMD successful, Duration 0.00 seconds
# ConvertToMD-[Notice] ConvertToMD started
# ConvertToMD-[Notice] ConvertToMD successful, Duration 0.21 seconds
# {'AlignedDim1': 'DeltaE,0,80, 160', 'AlignedDim0': '[H,0,0],-5,5,251', 'AlignedDim3': '[0,0,L],-1,1,1', 'AlignedDim2': '[0,K,0],-1,1,1'}
# MDNormDirectSC-[Notice] MDNormDirectSC started
# MDNormDirectSC-[Notice] MDNormDirectSC successful, Duration 3.58 seconds
# rotation angle #42: 36.0
# PlusMD-[Notice] PlusMD started
# PlusMD-[Notice] PlusMD successful, Duration 0.00 seconds
# PlusMD-[Notice] PlusMD started
# PlusMD-[Notice] PlusMD successful, Duration 0.00 seconds
# ConvertToMD-[Notice] ConvertToMD started
# ConvertToMD-[Notice] ConvertToMD successful, Duration 0.22 seconds
# {'AlignedDim1': 'DeltaE,0,80, 160', 'AlignedDim0': '[H,0,0],-5,5,251', 'AlignedDim3': '[0,0,L],-1,1,1', 'AlignedDim2': '[0,K,0],-1,1,1'}
# MDNormDirectSC-[Notice] MDNormDirectSC started
# MDNormDirectSC-[Notice] MDNormDirectSC successful, Duration 3.80 seconds
# rotation angle #43: 39.0
# PlusMD-[Notice] PlusMD started
# PlusMD-[Notice] PlusMD successful, Duration 0.00 seconds
# PlusMD-[Notice] PlusMD started
# PlusMD-[Notice] PlusMD successful, Duration 0.00 seconds
# ConvertToMD-[Notice] ConvertToMD started
# ConvertToMD-[Notice] ConvertToMD successful, Duration 0.21 seconds
# {'AlignedDim1': 'DeltaE,0,80, 160', 'AlignedDim0': '[H,0,0],-5,5,251', 'AlignedDim3': '[0,0,L],-1,1,1', 'AlignedDim2': '[0,K,0],-1,1,1'}
# MDNormDirectSC-[Notice] MDNormDirectSC started
# MDNormDirectSC-[Notice] MDNormDirectSC successful, Duration 4.09 seconds
# rotation angle #44: 42.0
# PlusMD-[Notice] PlusMD started
# PlusMD-[Notice] PlusMD successful, Duration 0.00 seconds
# PlusMD-[Notice] PlusMD started
# PlusMD-[Notice] PlusMD successful, Duration 0.00 seconds
# ConvertToMD-[Notice] ConvertToMD started
# ConvertToMD-[Notice] ConvertToMD successful, Duration 0.22 seconds
# {'AlignedDim1': 'DeltaE,0,80, 160', 'AlignedDim0': '[H,0,0],-5,5,251', 'AlignedDim3': '[0,0,L],-1,1,1', 'AlignedDim2': '[0,K,0],-1,1,1'}
# MDNormDirectSC-[Notice] MDNormDirectSC started
# MDNormDirectSC-[Notice] MDNormDirectSC successful, Duration 4.19 seconds
# rotation angle #45: 45.0
# PlusMD-[Notice] PlusMD started
# PlusMD-[Notice] PlusMD successful, Duration 0.00 seconds
# PlusMD-[Notice] PlusMD started
# PlusMD-[Notice] PlusMD successful, Duration 0.00 seconds
# ConvertToMD-[Notice] ConvertToMD started
# ConvertToMD-[Notice] ConvertToMD successful, Duration 0.21 seconds
# {'AlignedDim1': 'DeltaE,0,80, 160', 'AlignedDim0': '[H,0,0],-5,5,251', 'AlignedDim3': '[0,0,L],-1,1,1', 'AlignedDim2': '[0,K,0],-1,1,1'}
# MDNormDirectSC-[Notice] MDNormDirectSC started
# MDNormDirectSC-[Notice] MDNormDirectSC successful, Duration 4.51 seconds
# rotation angle #46: 48.0
# PlusMD-[Notice] PlusMD started
# PlusMD-[Notice] PlusMD successful, Duration 0.00 seconds
# PlusMD-[Notice] PlusMD started
# PlusMD-[Notice] PlusMD successful, Duration 0.00 seconds
# ConvertToMD-[Notice] ConvertToMD started
# ConvertToMD-[Notice] ConvertToMD successful, Duration 0.23 seconds
# {'AlignedDim1': 'DeltaE,0,80, 160', 'AlignedDim0': '[H,0,0],-5,5,251', 'AlignedDim3': '[0,0,L],-1,1,1', 'AlignedDim2': '[0,K,0],-1,1,1'}
# MDNormDirectSC-[Notice] MDNormDirectSC started
# MDNormDirectSC-[Notice] MDNormDirectSC successful, Duration 4.77 seconds
# rotation angle #47: 51.0
# PlusMD-[Notice] PlusMD started
# PlusMD-[Notice] PlusMD successful, Duration 0.00 seconds
# PlusMD-[Notice] PlusMD started
# PlusMD-[Notice] PlusMD successful, Duration 0.00 seconds
# ConvertToMD-[Notice] ConvertToMD started
# ConvertToMD-[Notice] ConvertToMD successful, Duration 0.23 seconds
# {'AlignedDim1': 'DeltaE,0,80, 160', 'AlignedDim0': '[H,0,0],-5,5,251', 'AlignedDim3': '[0,0,L],-1,1,1', 'AlignedDim2': '[0,K,0],-1,1,1'}
# MDNormDirectSC-[Notice] MDNormDirectSC started
# MDNormDirectSC-[Notice] MDNormDirectSC successful, Duration 5.10 seconds
# rotation angle #48: 54.0
# PlusMD-[Notice] PlusMD started
# PlusMD-[Notice] PlusMD successful, Duration 0.00 seconds
# PlusMD-[Notice] PlusMD started
# PlusMD-[Notice] PlusMD successful, Duration 0.00 seconds
# ConvertToMD-[Notice] ConvertToMD started
# ConvertToMD-[Notice] ConvertToMD successful, Duration 0.24 seconds
# {'AlignedDim1': 'DeltaE,0,80, 160', 'AlignedDim0': '[H,0,0],-5,5,251', 'AlignedDim3': '[0,0,L],-1,1,1', 'AlignedDim2': '[0,K,0],-1,1,1'}
# MDNormDirectSC-[Notice] MDNormDirectSC started
# MDNormDirectSC-[Notice] MDNormDirectSC successful, Duration 5.61 seconds
# rotation angle #49: 57.0
# PlusMD-[Notice] PlusMD started
# PlusMD-[Notice] PlusMD successful, Duration 0.00 seconds
# PlusMD-[Notice] PlusMD started
# PlusMD-[Notice] PlusMD successful, Duration 0.00 seconds
# ConvertToMD-[Notice] ConvertToMD started
# ConvertToMD-[Notice] ConvertToMD successful, Duration 0.23 seconds
# {'AlignedDim1': 'DeltaE,0,80, 160', 'AlignedDim0': '[H,0,0],-5,5,251', 'AlignedDim3': '[0,0,L],-1,1,1', 'AlignedDim2': '[0,K,0],-1,1,1'}
# MDNormDirectSC-[Notice] MDNormDirectSC started
# MDNormDirectSC-[Notice] MDNormDirectSC successful, Duration 6.12 seconds
# rotation angle #50: 60.0
# PlusMD-[Notice] PlusMD started
# PlusMD-[Notice] PlusMD successful, Duration 0.00 seconds
# PlusMD-[Notice] PlusMD started
# PlusMD-[Notice] PlusMD successful, Duration 0.00 seconds
# ConvertToMD-[Notice] ConvertToMD started
# ConvertToMD-[Notice] ConvertToMD successful, Duration 0.20 seconds
# {'AlignedDim1': 'DeltaE,0,80, 160', 'AlignedDim0': '[H,0,0],-5,5,251', 'AlignedDim3': '[0,0,L],-1,1,1', 'AlignedDim2': '[0,K,0],-1,1,1'}
# MDNormDirectSC-[Notice] MDNormDirectSC started
# MDNormDirectSC-[Notice] MDNormDirectSC successful, Duration 6.65 seconds
# rotation angle #51: 63.0
# PlusMD-[Notice] PlusMD started
# PlusMD-[Notice] PlusMD successful, Duration 0.00 seconds
# PlusMD-[Notice] PlusMD started
# PlusMD-[Notice] PlusMD successful, Duration 0.00 seconds
# ConvertToMD-[Notice] ConvertToMD started
# ConvertToMD-[Notice] ConvertToMD successful, Duration 0.22 seconds
# {'AlignedDim1': 'DeltaE,0,80, 160', 'AlignedDim0': '[H,0,0],-5,5,251', 'AlignedDim3': '[0,0,L],-1,1,1', 'AlignedDim2': '[0,K,0],-1,1,1'}
# MDNormDirectSC-[Notice] MDNormDirectSC started
# MDNormDirectSC-[Notice] MDNormDirectSC successful, Duration 7.33 seconds
# rotation angle #52: 66.0
# PlusMD-[Notice] PlusMD started
# PlusMD-[Notice] PlusMD successful, Duration 0.00 seconds
# PlusMD-[Notice] PlusMD started
# PlusMD-[Notice] PlusMD successful, Duration 0.00 seconds
# ConvertToMD-[Notice] ConvertToMD started
# ConvertToMD-[Notice] ConvertToMD successful, Duration 0.22 seconds
# {'AlignedDim1': 'DeltaE,0,80, 160', 'AlignedDim0': '[H,0,0],-5,5,251', 'AlignedDim3': '[0,0,L],-1,1,1', 'AlignedDim2': '[0,K,0],-1,1,1'}
# MDNormDirectSC-[Notice] MDNormDirectSC started
# MDNormDirectSC-[Notice] MDNormDirectSC successful, Duration 8.07 seconds
# rotation angle #53: 69.0
# PlusMD-[Notice] PlusMD started
# PlusMD-[Notice] PlusMD successful, Duration 0.00 seconds
# PlusMD-[Notice] PlusMD started
# PlusMD-[Notice] PlusMD successful, Duration 0.00 seconds
# ConvertToMD-[Notice] ConvertToMD started
# ConvertToMD-[Notice] ConvertToMD successful, Duration 0.22 seconds
# {'AlignedDim1': 'DeltaE,0,80, 160', 'AlignedDim0': '[H,0,0],-5,5,251', 'AlignedDim3': '[0,0,L],-1,1,1', 'AlignedDim2': '[0,K,0],-1,1,1'}
# MDNormDirectSC-[Notice] MDNormDirectSC started
# MDNormDirectSC-[Notice] MDNormDirectSC successful, Duration 9.07 seconds
# rotation angle #54: 72.0
# PlusMD-[Notice] PlusMD started
# PlusMD-[Notice] PlusMD successful, Duration 0.00 seconds
# PlusMD-[Notice] PlusMD started
# PlusMD-[Notice] PlusMD successful, Duration 0.00 seconds
# ConvertToMD-[Notice] ConvertToMD started
# ConvertToMD-[Notice] ConvertToMD successful, Duration 0.23 seconds
# {'AlignedDim1': 'DeltaE,0,80, 160', 'AlignedDim0': '[H,0,0],-5,5,251', 'AlignedDim3': '[0,0,L],-1,1,1', 'AlignedDim2': '[0,K,0],-1,1,1'}
# MDNormDirectSC-[Notice] MDNormDirectSC started
# MDNormDirectSC-[Notice] MDNormDirectSC successful, Duration 10.21 seconds
# rotation angle #55: 75.0
# PlusMD-[Notice] PlusMD started
# PlusMD-[Notice] PlusMD successful, Duration 0.00 seconds
# PlusMD-[Notice] PlusMD started
# PlusMD-[Notice] PlusMD successful, Duration 0.00 seconds
# ConvertToMD-[Notice] ConvertToMD started
# ConvertToMD-[Notice] ConvertToMD successful, Duration 0.20 seconds
# {'AlignedDim1': 'DeltaE,0,80, 160', 'AlignedDim0': '[H,0,0],-5,5,251', 'AlignedDim3': '[0,0,L],-1,1,1', 'AlignedDim2': '[0,K,0],-1,1,1'}
# MDNormDirectSC-[Notice] MDNormDirectSC started
# MDNormDirectSC-[Notice] MDNormDirectSC successful, Duration 11.47 seconds
# rotation angle #56: 78.0
# PlusMD-[Notice] PlusMD started
# PlusMD-[Notice] PlusMD successful, Duration 0.00 seconds
# PlusMD-[Notice] PlusMD started
# PlusMD-[Notice] PlusMD successful, Duration 0.00 seconds
# ConvertToMD-[Notice] ConvertToMD started
# ConvertToMD-[Notice] ConvertToMD successful, Duration 0.21 seconds
# {'AlignedDim1': 'DeltaE,0,80, 160', 'AlignedDim0': '[H,0,0],-5,5,251', 'AlignedDim3': '[0,0,L],-1,1,1', 'AlignedDim2': '[0,K,0],-1,1,1'}
# MDNormDirectSC-[Notice] MDNormDirectSC started
# MDNormDirectSC-[Notice] MDNormDirectSC successful, Duration 12.44 seconds
# rotation angle #57: 81.0
# PlusMD-[Notice] PlusMD started
# PlusMD-[Notice] PlusMD successful, Duration 0.00 seconds
# PlusMD-[Notice] PlusMD started
# PlusMD-[Notice] PlusMD successful, Duration 0.00 seconds
# ConvertToMD-[Notice] ConvertToMD started
# ConvertToMD-[Notice] ConvertToMD successful, Duration 0.20 seconds
# {'AlignedDim1': 'DeltaE,0,80, 160', 'AlignedDim0': '[H,0,0],-5,5,251', 'AlignedDim3': '[0,0,L],-1,1,1', 'AlignedDim2': '[0,K,0],-1,1,1'}
# MDNormDirectSC-[Notice] MDNormDirectSC started
# MDNormDirectSC-[Notice] MDNormDirectSC successful, Duration 13.52 seconds
# rotation angle #58: 84.0
# PlusMD-[Notice] PlusMD started
# PlusMD-[Notice] PlusMD successful, Duration 0.00 seconds
# PlusMD-[Notice] PlusMD started
# PlusMD-[Notice] PlusMD successful, Duration 0.00 seconds
# ConvertToMD-[Notice] ConvertToMD started
# ConvertToMD-[Notice] ConvertToMD successful, Duration 0.19 seconds
# {'AlignedDim1': 'DeltaE,0,80, 160', 'AlignedDim0': '[H,0,0],-5,5,251', 'AlignedDim3': '[0,0,L],-1,1,1', 'AlignedDim2': '[0,K,0],-1,1,1'}
# MDNormDirectSC-[Notice] MDNormDirectSC started
# MDNormDirectSC-[Notice] MDNormDirectSC successful, Duration 14.43 seconds
# rotation angle #59: 87.0
# PlusMD-[Notice] PlusMD started
# PlusMD-[Notice] PlusMD successful, Duration 0.00 seconds
# PlusMD-[Notice] PlusMD started
# PlusMD-[Notice] PlusMD successful, Duration 0.00 seconds
# ConvertToMD-[Notice] ConvertToMD started
# ConvertToMD-[Notice] ConvertToMD successful, Duration 0.19 seconds
# {'AlignedDim1': 'DeltaE,0,80, 160', 'AlignedDim0': '[H,0,0],-5,5,251', 'AlignedDim3': '[0,0,L],-1,1,1', 'AlignedDim2': '[0,K,0],-1,1,1'}
# MDNormDirectSC-[Notice] MDNormDirectSC started
# MDNormDirectSC-[Notice] MDNormDirectSC successful, Duration 15.32 seconds
# rotation angle #60: 90.0
# PlusMD-[Notice] PlusMD started
# PlusMD-[Notice] PlusMD successful, Duration 0.00 seconds
# PlusMD-[Notice] PlusMD started
# PlusMD-[Notice] PlusMD successful, Duration 0.00 seconds
# RemoveWorkspaceHistory-[Notice] RemoveWorkspaceHistory started
# RemoveWorkspaceHistory-[Notice] RemoveWorkspaceHistory successful, Duration 0.00 seconds
# RemoveWorkspaceHistory-[Notice] RemoveWorkspaceHistory started
# RemoveWorkspaceHistory-[Notice] RemoveWorkspaceHistory successful, Duration 0.00 seconds
# SmoothMD-[Notice] SmoothMD started
# SmoothMD-[Notice] SmoothMD successful, Duration 0.01 seconds
# SmoothMD-[Notice] SmoothMD started
# SmoothMD-[Notice] SmoothMD successful, Duration 0.01 seconds
# DivideMD-[Notice] DivideMD started
# DivideMD-[Notice] DivideMD successful, Duration 0.00 seconds
# SaveMD-[Notice] SaveMD started
# SaveMD-[Notice] SaveMD successful, Duration 0.81 seconds

# %%
# convert slice nexus to slice histogram for plotting
# !./scripts/reduce/slice2hist.py slice_H00.nxs slice_H00.h5
# Out:
# FrameworkManager-[Notice] Welcome to Mantid 3.6.100
# FrameworkManager-[Notice] Please cite: http://dx.doi.org/10.1016/j.nima.2014.07.029 and this release: http://dx.doi.org/10.5286/Software/Mantid3.6.100
# Load-[Notice] Load started
# Load-[Notice] Load successful, Duration 1.35 seconds

# %%
# plot
H.plot(hh.load("./slice_H00.h5"), min=0, max=1e-6)
# Out:
# /SNS/users/lj7/software/miniconda2/envs/mcvine/lib/python2.7/site-packages/histogram/hdf/Loader.py:129: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if 'storage' in list(dataGroup): # this uses the 'storage' convention
# plot z in (0, 1e-06)
# /SNS/users/lj7/software/miniconda2/envs/mcvine/lib/python2.7/site-packages/histogram/data_plotter.py:352: RuntimeWarning: invalid value encountered in less
#   negative_median = N.median( z[ z<0 ] )
# /SNS/users/lj7/software/miniconda2/envs/mcvine/lib/python2.7/site-packages/numpy/core/_methods.py:59: RuntimeWarning: Mean of empty slice.
#   warnings.warn("Mean of empty slice.", RuntimeWarning)
# /SNS/users/lj7/software/miniconda2/envs/mcvine/lib/python2.7/site-packages/numpy/core/_methods.py:70: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /SNS/users/lj7/software/miniconda2/envs/mcvine/lib/python2.7/site-packages/histogram/data_plotter.py:334: RuntimeWarning: invalid value encountered in greater
#   positive_median = N.median( z[ z>0 ] )
# <img src="data:image/png;base64,...">

# %%
# %%file slice_H00_-2,0.yml
#
# angles: -90,90.1,3.0
# filename_pattern: work_%(angle)s/reduced_%(angle)s.nxs
# lattice: 2., 2.5, 3., 90, 90, 90
# orientation:
#  u: 1, 0, 2
#  v: 1,0,0
# Eaxis:
#  min: 0
#  max: 90
#  N: 180
# Q_projections:
#  U:
#   proj: 1,0,0
#   proj_name: H,0,0
#   min: -2.1
#   max: 0.1
#   N: 56
#  V:
#   proj: 0,1,0
#   proj_name: 0,K,0
#   min: -1
#   max: 1
#   N: 1
#  W:
#   proj: 0,0,1
#   proj_name: 0,0,L
#   min: -1
#   max: 1
#   N: 1
# output: slice_H00_-2__0.nxs
# Out:
# Overwriting slice_H00_-2,0.yml

# %%
! PYTHONPATH=$PWD:$PYTHONPATH ./scripts/reduce/getaslice.py slice_H00_-2,0.yml
# Out:
# -90.0 work_-90.0/reduced_-90.0.nxs
# FrameworkManager-[Notice] Welcome to Mantid 3.6.100
# FrameworkManager-[Notice] Please cite: http://dx.doi.org/10.1016/j.nima.2014.07.029 and this release: http://dx.doi.org/10.5286/Software/Mantid3.6.100
# Load-[Notice] Load started
# Load-[Notice] Load successful, Duration 59.41 seconds
# CompressEvents-[Notice] CompressEvents started
# CompressEvents-[Notice] CompressEvents started
# CompressEvents-[Notice] CompressEvents successful, Duration 0.55 seconds
# CompressEvents-[Notice] CompressEvents started
# CompressEvents-[Notice] CompressEvents successful, Duration 0.60 seconds
# CompressEvents-[Notice] CompressEvents started
# CompressEvents-[Notice] CompressEvents successful, Duration 0.60 seconds
# CompressEvents-[Notice] CompressEvents started
# CompressEvents-[Notice] CompressEvents successful, Duration 0.82 seconds
# CompressEvents-[Notice] CompressEvents started
# CompressEvents-[Notice] CompressEvents successful, Duration 0.88 seconds
# CompressEvents-[Notice] CompressEvents started
# CompressEvents-[Notice] CompressEvents successful, Duration 0.63 seconds
# CompressEvents-[Notice] CompressEvents started
# CompressEvents-[Notice] CompressEvents successful, Duration 0.86 seconds
# CompressEvents-[Notice] CompressEvents started
# CompressEvents-[Notice] CompressEvents successful, Duration 1.25 seconds
# CompressEvents-[Notice] CompressEvents started
# CompressEvents-[Notice] CompressEvents successful, Duration 0.60 seconds
# CompressEvents-[Notice] CompressEvents started
# CompressEvents-[Notice] CompressEvents successful, Duration 1.34 seconds
# CompressEvents-[Notice] CompressEvents started
# CompressEvents-[Notice] CompressEvents successful, Duration 0.62 seconds
# CompressEvents-[Notice] CompressEvents started
# CompressEvents-[Notice] CompressEvents successful, Duration 1.00 seconds
# CompressEvents-[Notice] CompressEvents started
# CompressEvents-[Notice] CompressEvents successful, Duration 0.78 seconds
# CompressEvents-[Notice] CompressEvents started
# CompressEvents-[Notice] CompressEvents successful, Duration 0.65 seconds
# CompressEvents-[Notice] CompressEvents started
# CompressEvents-[Notice] CompressEvents successful, Duration 0.81 seconds
# CompressEvents-[Notice] CompressEvents started
# CompressEvents-[Notice] CompressEvents successful, Duration 0.71 seconds
# CompressEvents-[Notice] CompressEvents started
# CompressEvents-[Notice] CompressEvents successful, Duration 0.62 seconds
# CompressEvents-[Notice] CompressEvents started
# CompressEvents-[Notice] CompressEvents successful, Duration 0.65 seconds
# CompressEvents-[Notice] CompressEvents started
# CompressEvents-[Notice] CompressEvents successful, Duration 0.66 seconds
# CompressEvents-[Notice] CompressEvents started
# CompressEvents-[Notice] CompressEvents successful, Duration 0.61 seconds
# CompressEvents-[Notice] CompressEvents started
# CompressEvents-[Notice] CompressEvents successful, Duration 1.30 seconds
# CompressEvents-[Notice] CompressEvents started
# CompressEvents-[Notice] CompressEvents successful, Duration 0.68 seconds
# CompressEvents-[Notice] CompressEvents started
# CompressEvents-[Notice] CompressEvents successful, Duration 0.65 seconds
# CompressEvents-[Notice] CompressEvents started
# CompressEvents-[Notice] CompressEvents successful, Duration 0.91 seconds
# CompressEvents-[Notice] CompressEvents started
# CompressEvents-[Notice] CompressEvents successful, Duration 0.59 seconds
# CompressEvents-[Notice] CompressEvents started
# CompressEvents-[Notice] CompressEvents successful, Duration 0.65 seconds
# CompressEvents-[Notice] CompressEvents started
# CompressEvents-[Notice] CompressEvents successful, Duration 1.04 seconds
# CompressEvents-[Notice] CompressEvents started
# CompressEvents-[Notice] CompressEvents successful, Duration 0.98 seconds
# CompressEvents-[Notice] CompressEvents started
# CompressEvents-[Notice] CompressEvents successful, Duration 0.75 seconds
# CompressEvents-[Notice] CompressEvents started
# CompressEvents-[Notice] CompressEvents successful, Duration 0.77 seconds
# CompressEvents-[Notice] CompressEvents started
# CompressEvents-[Notice] CompressEvents successful, Duration 0.68 seconds
# CompressEvents-[Notice] CompressEvents started
# CompressEvents-[Notice] CompressEvents successful, Duration 0.96 seconds
# CompressEvents-[Notice] CompressEvents started
# CompressEvents-[Notice] CompressEvents successful, Duration 0.60 seconds
# CompressEvents-[Notice] CompressEvents started
# CompressEvents-[Notice] CompressEvents successful, Duration 0.69 seconds
# CompressEvents-[Notice] CompressEvents started
# CompressEvents-[Notice] CompressEvents successful, Duration 0.90 seconds
# CompressEvents-[Notice] CompressEvents started
# CompressEvents-[Notice] CompressEvents successful, Duration 0.65 seconds
# CompressEvents-[Notice] CompressEvents started
# CompressEvents-[Notice] CompressEvents successful, Duration 0.68 seconds
# CompressEvents-[Notice] CompressEvents started
# CompressEvents-[Notice] CompressEvents successful, Duration 0.85 seconds
# CompressEvents-[Notice] CompressEvents started
# CompressEvents-[Notice] CompressEvents successful, Duration 0.91 seconds
# CompressEvents-[Notice] CompressEvents started
# CompressEvents-[Notice] CompressEvents successful, Duration 0.69 seconds
# CompressEvents-[Notice] CompressEvents started
# CompressEvents-[Notice] CompressEvents successful, Duration 0.59 seconds
# CompressEvents-[Notice] CompressEvents started
# CompressEvents-[Notice] CompressEvents successful, Duration 0.85 seconds
# CompressEvents-[Notice] CompressEvents started
# CompressEvents-[Notice] CompressEvents successful, Duration 0.57 seconds
# CompressEvents-[Notice] CompressEvents started
# CompressEvents-[Notice] CompressEvents successful, Duration 0.80 seconds
# CompressEvents-[Notice] CompressEvents started
# CompressEvents-[Notice] CompressEvents successful, Duration 0.58 seconds
# CompressEvents-[Notice] CompressEvents started
# CompressEvents-[Notice] CompressEvents successful, Duration 0.66 seconds
# CompressEvents-[Notice] CompressEvents started
# CompressEvents-[Notice] CompressEvents successful, Duration 0.61 seconds
# CompressEvents-[Notice] CompressEvents started
# CompressEvents-[Notice] CompressEvents successful, Duration 0.83 seconds
# CompressEvents-[Notice] CompressEvents started
# CompressEvents-[Notice] CompressEvents successful, Duration 0.70 seconds
# CompressEvents-[Notice] CompressEvents started
# CompressEvents-[Notice] CompressEvents successful, Duration 0.62 seconds
# CompressEvents-[Notice] CompressEvents started
# CompressEvents-[Notice] CompressEvents successful, Duration 0.59 seconds
# CompressEvents-[Notice] CompressEvents started
# CompressEvents-[Notice] CompressEvents successful, Duration 0.64 seconds
# CompressEvents-[Notice] CompressEvents started
# CompressEvents-[Notice] CompressEvents successful, Duration 0.59 seconds
# CompressEvents-[Notice] CompressEvents started
# CompressEvents-[Notice] CompressEvents successful, Duration 0.63 seconds
# CompressEvents-[Notice] CompressEvents started
# CompressEvents-[Notice] CompressEvents successful, Duration 0.60 seconds
# CompressEvents-[Notice] CompressEvents started
# CompressEvents-[Notice] CompressEvents successful, Duration 0.61 seconds
# CompressEvents-[Notice] CompressEvents started
# CompressEvents-[Notice] CompressEvents successful, Duration 0.59 seconds
# CompressEvents-[Notice] CompressEvents started
# CompressEvents-[Notice] CompressEvents successful, Duration 0.60 seconds
# CompressEvents-[Notice] CompressEvents started
# CompressEvents-[Notice] CompressEvents successful, Duration 0.57 seconds
# CompressEvents-[Notice] CompressEvents started
# CompressEvents-[Notice] CompressEvents successful, Duration 0.58 seconds
# CompressEvents-[Notice] CompressEvents started
# CompressEvents-[Notice] CompressEvents successful, Duration 0.76 seconds
# CompressEvents-[Notice] CompressEvents successful, Duration 44.80 seconds. Processed as a workspace group
# DeleteWorkspace-[Notice] DeleteWorkspace started
# DeleteWorkspace-[Notice] DeleteWorkspace started
# DeleteWorkspace-[Notice] DeleteWorkspace successful, Duration 0.00 seconds
# DeleteWorkspace-[Notice] DeleteWorkspace started
# DeleteWorkspace-[Notice] DeleteWorkspace successful, Duration 0.00 seconds
# DeleteWorkspace-[Notice] DeleteWorkspace started
# DeleteWorkspace-[Notice] DeleteWorkspace successful, Duration 0.00 seconds
# DeleteWorkspace-[Notice] DeleteWorkspace started
# DeleteWorkspace-[Notice] DeleteWorkspace successful, Duration 0.00 seconds
# DeleteWorkspace-[Notice] DeleteWorkspace started
# DeleteWorkspace-[Notice] DeleteWorkspace successful, Duration 0.00 seconds
# DeleteWorkspace-[Notice] DeleteWorkspace started
# DeleteWorkspace-[Notice] DeleteWorkspace successful, Duration 0.00 seconds
# DeleteWorkspace-[Notice] DeleteWorkspace started
# DeleteWorkspace-[Notice] DeleteWorkspace successful, Duration 0.00 seconds
# DeleteWorkspace-[Notice] DeleteWorkspace started
# DeleteWorkspace-[Notice] DeleteWorkspace successful, Duration 0.00 seconds
# DeleteWorkspace-[Notice] DeleteWorkspace started
# DeleteWorkspace-[Notice] DeleteWorkspace successful, Duration 0.00 seconds
# DeleteWorkspace-[Notice] DeleteWorkspace started
# DeleteWorkspace-[Notice] DeleteWorkspace successful, Duration 0.00 seconds
# DeleteWorkspace-[Notice] DeleteWorkspace started
# DeleteWorkspace-[Notice] DeleteWorkspace successful, Duration 0.00 seconds
# DeleteWorkspace-[Notice] DeleteWorkspace started
# DeleteWorkspace-[Notice] DeleteWorkspace successful, Duration 0.00 seconds
# DeleteWorkspace-[Notice] DeleteWorkspace started
# DeleteWorkspace-[Notice] DeleteWorkspace successful, Duration 0.00 seconds
# DeleteWorkspace-[Notice] DeleteWorkspace started
# DeleteWorkspace-[Notice] DeleteWorkspace successful, Duration 0.00 seconds
# DeleteWorkspace-[Notice] DeleteWorkspace started
# DeleteWorkspace-[Notice] DeleteWorkspace successful, Duration 0.00 seconds
# DeleteWorkspace-[Notice] DeleteWorkspace started
# DeleteWorkspace-[Notice] DeleteWorkspace successful, Duration 0.00 seconds
# DeleteWorkspace-[Notice] DeleteWorkspace started
# DeleteWorkspace-[Notice] DeleteWorkspace successful, Duration 0.00 seconds
# DeleteWorkspace-[Notice] DeleteWorkspace started
# DeleteWorkspace-[Notice] DeleteWorkspace successful, Duration 0.00 seconds
# DeleteWorkspace-[Notice] DeleteWorkspace started
# DeleteWorkspace-[Notice] DeleteWorkspace successful, Duration 0.00 seconds
# DeleteWorkspace-[Notice] DeleteWorkspace started
# DeleteWorkspace-[Notice] DeleteWorkspace successful, Duration 0.00 seconds
# DeleteWorkspace-[Notice] DeleteWorkspace started
# DeleteWorkspace-[Notice] DeleteWorkspace successful, Duration 0.00 seconds
# DeleteWorkspace-[Notice] DeleteWorkspace started
# DeleteWorkspace-[Notice] DeleteWorkspace successful, Duration 0.00 seconds
# DeleteWorkspace-[Notice] DeleteWorkspace started
# DeleteWorkspace-[Notice] DeleteWorkspace successful, Duration 0.00 seconds
# DeleteWorkspace-[Notice] DeleteWorkspace started
# DeleteWorkspace-[Notice] DeleteWorkspace successful, Duration 0.00 seconds
# DeleteWorkspace-[Notice] DeleteWorkspace started
# DeleteWorkspace-[Notice] DeleteWorkspace successful, Duration 0.00 seconds
# DeleteWorkspace-[Notice] DeleteWorkspace started
# DeleteWorkspace-[Notice] DeleteWorkspace successful, Duration 0.00 seconds
# DeleteWorkspace-[Notice] DeleteWorkspace started
# DeleteWorkspace-[Notice] DeleteWorkspace successful, Duration 0.00 seconds
# DeleteWorkspace-[Notice] DeleteWorkspace started
# DeleteWorkspace-[Notice] DeleteWorkspace successful, Duration 0.00 seconds
# DeleteWorkspace-[Notice] DeleteWorkspace started
# DeleteWorkspace-[Notice] DeleteWorkspace successful, Duration 0.00 seconds
# DeleteWorkspace-[Notice] DeleteWorkspace started
# DeleteWorkspace-[Notice] DeleteWorkspace successful, Duration 0.00 seconds
# DeleteWorkspace-[Notice] DeleteWorkspace started
# DeleteWorkspace-[Notice] DeleteWorkspace successful, Duration 0.00 seconds
# DeleteWorkspace-[Notice] DeleteWorkspace started
# DeleteWorkspace-[Notice] DeleteWorkspace successful, Duration 0.00 seconds
# DeleteWorkspace-[Notice] DeleteWorkspace started
# DeleteWorkspace-[Notice] DeleteWorkspace successful, Duration 0.00 seconds
# DeleteWorkspace-[Notice] DeleteWorkspace started
# DeleteWorkspace-[Notice] DeleteWorkspace successful, Duration 0.00 seconds
# DeleteWorkspace-[Notice] DeleteWorkspace started
# DeleteWorkspace-[Notice] DeleteWorkspace successful, Duration 0.00 seconds
# DeleteWorkspace-[Notice] DeleteWorkspace started
# DeleteWorkspace-[Notice] DeleteWorkspace successful, Duration 0.00 seconds
# DeleteWorkspace-[Notice] DeleteWorkspace started
# DeleteWorkspace-[Notice] DeleteWorkspace successful, Duration 0.00 seconds
# DeleteWorkspace-[Notice] DeleteWorkspace started
# DeleteWorkspace-[Notice] DeleteWorkspace successful, Duration 0.00 seconds
# DeleteWorkspace-[Notice] DeleteWorkspace started
# DeleteWorkspace-[Notice] DeleteWorkspace successful, Duration 0.00 seconds
# DeleteWorkspace-[Notice] DeleteWorkspace started
# DeleteWorkspace-[Notice] DeleteWorkspace successful, Duration 0.00 seconds
# DeleteWorkspace-[Notice] DeleteWorkspace started
# DeleteWorkspace-[Notice] DeleteWorkspace successful, Duration 0.00 seconds
# DeleteWorkspace-[Notice] DeleteWorkspace started
# DeleteWorkspace-[Notice] DeleteWorkspace successful, Duration 0.00 seconds
# DeleteWorkspace-[Notice] DeleteWorkspace started
# DeleteWorkspace-[Notice] DeleteWorkspace successful, Duration 0.00 seconds
# DeleteWorkspace-[Notice] DeleteWorkspace started
# DeleteWorkspace-[Notice] DeleteWorkspace successful, Duration 0.00 seconds
# DeleteWorkspace-[Notice] DeleteWorkspace started
# DeleteWorkspace-[Notice] DeleteWorkspace successful, Duration 0.00 seconds
# DeleteWorkspace-[Notice] DeleteWorkspace started
# DeleteWorkspace-[Notice] DeleteWorkspace successful, Duration 0.00 seconds
# DeleteWorkspace-[Notice] DeleteWorkspace started
# DeleteWorkspace-[Notice] DeleteWorkspace successful, Duration 0.00 seconds
# DeleteWorkspace-[Notice] DeleteWorkspace started
# DeleteWorkspace-[Notice] DeleteWorkspace successful, Duration 0.00 seconds
# DeleteWorkspace-[Notice] DeleteWorkspace started
# DeleteWorkspace-[Notice] DeleteWorkspace successful, Duration 0.00 seconds
# DeleteWorkspace-[Notice] DeleteWorkspace started
# DeleteWorkspace-[Notice] DeleteWorkspace successful, Duration 0.00 seconds
# DeleteWorkspace-[Notice] DeleteWorkspace started
# DeleteWorkspace-[Notice] DeleteWorkspace successful, Duration 0.00 seconds
# DeleteWorkspace-[Notice] DeleteWorkspace started
# DeleteWorkspace-[Notice] DeleteWorkspace successful, Duration 0.00 seconds
# DeleteWorkspace-[Notice] DeleteWorkspace started
# DeleteWorkspace-[Notice] DeleteWorkspace successful, Duration 0.00 seconds
# DeleteWorkspace-[Notice] DeleteWorkspace started
# DeleteWorkspace-[Notice] DeleteWorkspace successful, Duration 0.00 seconds
# DeleteWorkspace-[Notice] DeleteWorkspace started
# DeleteWorkspace-[Notice] DeleteWorkspace successful, Duration 0.00 seconds
# DeleteWorkspace-[Notice] DeleteWorkspace started
# DeleteWorkspace-[Notice] DeleteWorkspace successful, Duration 0.00 seconds
# DeleteWorkspace-[Notice] DeleteWorkspace started
# DeleteWorkspace-[Notice] DeleteWorkspace successful, Duration 0.00 seconds
# DeleteWorkspace-[Notice] DeleteWorkspace started
# DeleteWorkspace-[Notice] DeleteWorkspace successful, Duration 0.00 seconds
# DeleteWorkspace-[Notice] DeleteWorkspace started
# DeleteWorkspace-[Notice] DeleteWorkspace successful, Duration 0.00 seconds
# DeleteWorkspace-[Notice] DeleteWorkspace started
# DeleteWorkspace-[Notice] DeleteWorkspace successful, Duration 0.00 seconds
# DeleteWorkspace-[Notice] DeleteWorkspace started
# DeleteWorkspace-[Notice] DeleteWorkspace successful, Duration 0.00 seconds
# DeleteWorkspace-[Notice] DeleteWorkspace successful, Duration 0.02 seconds. Processed as a workspace group
# SetGoniometer-[Notice] SetGoniometer started
# SetGoniometer-[Notice] SetGoniometer started
# SetGoniometer-[Notice] SetGoniometer successful, Duration 0.00 seconds
# SetGoniometer-[Notice] SetGoniometer started
# SetGoniometer-[Notice] SetGoniometer successful, Duration 0.00 seconds
# SetGoniometer-[Notice] SetGoniometer started
# SetGoniometer-[Notice] SetGoniometer successful, Duration 0.00 seconds
# SetGoniometer-[Notice] SetGoniometer started
# SetGoniometer-[Notice] SetGoniometer successful, Duration 0.00 seconds
# SetGoniometer-[Notice] SetGoniometer started
# SetGoniometer-[Notice] SetGoniometer successful, Duration 0.00 seconds
# SetGoniometer-[Notice] SetGoniometer started
# SetGoniometer-[Notice] SetGoniometer successful, Duration 0.00 seconds
# SetGoniometer-[Notice] SetGoniometer started
# SetGoniometer-[Notice] SetGoniometer successful, Duration 0.00 seconds
# SetGoniometer-[Notice] SetGoniometer started
# SetGoniometer-[Notice] SetGoniometer successful, Duration 0.00 seconds
# SetGoniometer-[Notice] SetGoniometer started
# SetGoniometer-[Notice] SetGoniometer successful, Duration 0.00 seconds
# SetGoniometer-[Notice] SetGoniometer started
# SetGoniometer-[Notice] SetGoniometer successful, Duration 0.00 seconds
# SetGoniometer-[Notice] SetGoniometer started
# SetGoniometer-[Notice] SetGoniometer successful, Duration 0.00 seconds
# SetGoniometer-[Notice] SetGoniometer started
# SetGoniometer-[Notice] SetGoniometer successful, Duration 0.00 seconds
# SetGoniometer-[Notice] SetGoniometer started
# SetGoniometer-[Notice] SetGoniometer successful, Duration 0.00 seconds
# SetGoniometer-[Notice] SetGoniometer started
# SetGoniometer-[Notice] SetGoniometer successful, Duration 0.00 seconds
# SetGoniometer-[Notice] SetGoniometer started
# SetGoniometer-[Notice] SetGoniometer successful, Duration 0.00 seconds
# SetGoniometer-[Notice] SetGoniometer started
# SetGoniometer-[Notice] SetGoniometer successful, Duration 0.00 seconds
# SetGoniometer-[Notice] SetGoniometer started
# SetGoniometer-[Notice] SetGoniometer successful, Duration 0.00 seconds
# SetGoniometer-[Notice] SetGoniometer started
# SetGoniometer-[Notice] SetGoniometer successful, Duration 0.00 seconds
# SetGoniometer-[Notice] SetGoniometer started
# SetGoniometer-[Notice] SetGoniometer successful, Duration 0.00 seconds
# SetGoniometer-[Notice] SetGoniometer started
# SetGoniometer-[Notice] SetGoniometer successful, Duration 0.00 seconds
# SetGoniometer-[Notice] SetGoniometer started
# SetGoniometer-[Notice] SetGoniometer successful, Duration 0.00 seconds
# SetGoniometer-[Notice] SetGoniometer started
# SetGoniometer-[Notice] SetGoniometer successful, Duration 0.00 seconds
# SetGoniometer-[Notice] SetGoniometer started
# SetGoniometer-[Notice] SetGoniometer successful, Duration 0.00 seconds
# SetGoniometer-[Notice] SetGoniometer started
# SetGoniometer-[Notice] SetGoniometer successful, Duration 0.00 seconds
# SetGoniometer-[Notice] SetGoniometer started
# SetGoniometer-[Notice] SetGoniometer successful, Duration 0.00 seconds
# SetGoniometer-[Notice] SetGoniometer started
# SetGoniometer-[Notice] SetGoniometer successful, Duration 0.00 seconds
# SetGoniometer-[Notice] SetGoniometer started
# SetGoniometer-[Notice] SetGoniometer successful, Duration 0.00 seconds
# SetGoniometer-[Notice] SetGoniometer started
# SetGoniometer-[Notice] SetGoniometer successful, Duration 0.00 seconds
# SetGoniometer-[Notice] SetGoniometer started
# SetGoniometer-[Notice] SetGoniometer successful, Duration 0.00 seconds
# SetGoniometer-[Notice] SetGoniometer started
# SetGoniometer-[Notice] SetGoniometer successful, Duration 0.00 seconds
# SetGoniometer-[Notice] SetGoniometer started
# SetGoniometer-[Notice] SetGoniometer successful, Duration 0.00 seconds
# SetGoniometer-[Notice] SetGoniometer started
# SetGoniometer-[Notice] SetGoniometer successful, Duration 0.00 seconds
# SetGoniometer-[Notice] SetGoniometer started
# SetGoniometer-[Notice] SetGoniometer successful, Duration 0.00 seconds
# SetGoniometer-[Notice] SetGoniometer started
# SetGoniometer-[Notice] SetGoniometer successful, Duration 0.00 seconds
# SetGoniometer-[Notice] SetGoniometer started
# SetGoniometer-[Notice] SetGoniometer successful, Duration 0.00 seconds
# SetGoniometer-[Notice] SetGoniometer started
# SetGoniometer-[Notice] SetGoniometer successful, Duration 0.00 seconds
# SetGoniometer-[Notice] SetGoniometer started
# SetGoniometer-[Notice] SetGoniometer successful, Duration 0.00 seconds
# SetGoniometer-[Notice] SetGoniometer started
# SetGoniometer-[Notice] SetGoniometer successful, Duration 0.00 seconds
# SetGoniometer-[Notice] SetGoniometer started
# SetGoniometer-[Notice] SetGoniometer successful, Duration 0.00 seconds
# SetGoniometer-[Notice] SetGoniometer started
# SetGoniometer-[Notice] SetGoniometer successful, Duration 0.00 seconds
# SetGoniometer-[Notice] SetGoniometer started
# SetGoniometer-[Notice] SetGoniometer successful, Duration 0.00 seconds
# SetGoniometer-[Notice] SetGoniometer started
# SetGoniometer-[Notice] SetGoniometer successful, Duration 0.00 seconds
# SetGoniometer-[Notice] SetGoniometer started
# SetGoniometer-[Notice] SetGoniometer successful, Duration 0.00 seconds
# SetGoniometer-[Notice] SetGoniometer started
# SetGoniometer-[Notice] SetGoniometer successful, Duration 0.00 seconds
# SetGoniometer-[Notice] SetGoniometer started
# SetGoniometer-[Notice] SetGoniometer successful, Duration 0.00 seconds
# SetGoniometer-[Notice] SetGoniometer started
# SetGoniometer-[Notice] SetGoniometer successful, Duration 0.00 seconds
# SetGoniometer-[Notice] SetGoniometer started
# SetGoniometer-[Notice] SetGoniometer successful, Duration 0.00 seconds
# SetGoniometer-[Notice] SetGoniometer started
# SetGoniometer-[Notice] SetGoniometer successful, Duration 0.00 seconds
# SetGoniometer-[Notice] SetGoniometer started
# SetGoniometer-[Notice] SetGoniometer successful, Duration 0.00 seconds
# SetGoniometer-[Notice] SetGoniometer started
# SetGoniometer-[Notice] SetGoniometer successful, Duration 0.00 seconds
# SetGoniometer-[Notice] SetGoniometer started
# SetGoniometer-[Notice] SetGoniometer successful, Duration 0.00 seconds
# SetGoniometer-[Notice] SetGoniometer started
# SetGoniometer-[Notice] SetGoniometer successful, Duration 0.00 seconds
# SetGoniometer-[Notice] SetGoniometer started
# SetGoniometer-[Notice] SetGoniometer successful, Duration 0.00 seconds
# SetGoniometer-[Notice] SetGoniometer started
# SetGoniometer-[Notice] SetGoniometer successful, Duration 0.00 seconds
# SetGoniometer-[Notice] SetGoniometer started
# SetGoniometer-[Notice] SetGoniometer successful, Duration 0.00 seconds
# SetGoniometer-[Notice] SetGoniometer started
# SetGoniometer-[Notice] SetGoniometer successful, Duration 0.00 seconds
# SetGoniometer-[Notice] SetGoniometer started
# SetGoniometer-[Notice] SetGoniometer successful, Duration 0.00 seconds
# SetGoniometer-[Notice] SetGoniometer started
# SetGoniometer-[Notice] SetGoniometer successful, Duration 0.00 seconds
# SetGoniometer-[Notice] SetGoniometer started
# SetGoniometer-[Notice] SetGoniometer successful, Duration 0.00 seconds
# SetGoniometer-[Notice] SetGoniometer started
# SetGoniometer-[Notice] SetGoniometer successful, Duration 0.00 seconds
# SetGoniometer-[Notice] SetGoniometer started
# SetGoniometer-[Notice] SetGoniometer successful, Duration 0.00 seconds
# SetGoniometer-[Notice] SetGoniometer successful, Duration 0.06 seconds. Processed as a workspace group
# SetUB-[Notice] SetUB started
# SetUB-[Notice] SetUB started
# SetUB-[Notice] SetUB successful, Duration 0.00 seconds
# SetUB-[Notice] SetUB started
# SetUB-[Notice] SetUB successful, Duration 0.00 seconds
# SetUB-[Notice] SetUB started
# SetUB-[Notice] SetUB successful, Duration 0.00 seconds
# SetUB-[Notice] SetUB started
# SetUB-[Notice] SetUB successful, Duration 0.00 seconds
# SetUB-[Notice] SetUB started
# SetUB-[Notice] SetUB successful, Duration 0.00 seconds
# SetUB-[Notice] SetUB started
# SetUB-[Notice] SetUB successful, Duration 0.00 seconds
# SetUB-[Notice] SetUB started
# SetUB-[Notice] SetUB successful, Duration 0.00 seconds
# SetUB-[Notice] SetUB started
# SetUB-[Notice] SetUB successful, Duration 0.00 seconds
# SetUB-[Notice] SetUB started
# SetUB-[Notice] SetUB successful, Duration 0.00 seconds
# SetUB-[Notice] SetUB started
# SetUB-[Notice] SetUB successful, Duration 0.00 seconds
# SetUB-[Notice] SetUB started
# SetUB-[Notice] SetUB successful, Duration 0.00 seconds
# SetUB-[Notice] SetUB started
# SetUB-[Notice] SetUB successful, Duration 0.00 seconds
# SetUB-[Notice] SetUB started
# SetUB-[Notice] SetUB successful, Duration 0.00 seconds
# SetUB-[Notice] SetUB started
# SetUB-[Notice] SetUB successful, Duration 0.00 seconds
# SetUB-[Notice] SetUB started
# SetUB-[Notice] SetUB successful, Duration 0.00 seconds
# SetUB-[Notice] SetUB started
# SetUB-[Notice] SetUB successful, Duration 0.00 seconds
# SetUB-[Notice] SetUB started
# SetUB-[Notice] SetUB successful, Duration 0.00 seconds
# SetUB-[Notice] SetUB started
# SetUB-[Notice] SetUB successful, Duration 0.00 seconds
# SetUB-[Notice] SetUB started
# SetUB-[Notice] SetUB successful, Duration 0.00 seconds
# SetUB-[Notice] SetUB started
# SetUB-[Notice] SetUB successful, Duration 0.00 seconds
# SetUB-[Notice] SetUB started
# SetUB-[Notice] SetUB successful, Duration 0.00 seconds
# SetUB-[Notice] SetUB started
# SetUB-[Notice] SetUB successful, Duration 0.00 seconds
# SetUB-[Notice] SetUB started
# SetUB-[Notice] SetUB successful, Duration 0.00 seconds
# SetUB-[Notice] SetUB started
# SetUB-[Notice] SetUB successful, Duration 0.00 seconds
# SetUB-[Notice] SetUB started
# SetUB-[Notice] SetUB successful, Duration 0.00 seconds
# SetUB-[Notice] SetUB started
# SetUB-[Notice] SetUB successful, Duration 0.00 seconds
# SetUB-[Notice] SetUB started
# SetUB-[Notice] SetUB successful, Duration 0.00 seconds
# SetUB-[Notice] SetUB started
# SetUB-[Notice] SetUB successful, Duration 0.00 seconds
# SetUB-[Notice] SetUB started
# SetUB-[Notice] SetUB successful, Duration 0.00 seconds
# SetUB-[Notice] SetUB started
# SetUB-[Notice] SetUB successful, Duration 0.00 seconds
# SetUB-[Notice] SetUB started
# SetUB-[Notice] SetUB successful, Duration 0.00 seconds
# SetUB-[Notice] SetUB started
# SetUB-[Notice] SetUB successful, Duration 0.00 seconds
# SetUB-[Notice] SetUB started
# SetUB-[Notice] SetUB successful, Duration 0.00 seconds
# SetUB-[Notice] SetUB started
# SetUB-[Notice] SetUB successful, Duration 0.00 seconds
# SetUB-[Notice] SetUB started
# SetUB-[Notice] SetUB successful, Duration 0.00 seconds
# SetUB-[Notice] SetUB started
# SetUB-[Notice] SetUB successful, Duration 0.00 seconds
# SetUB-[Notice] SetUB started
# SetUB-[Notice] SetUB successful, Duration 0.00 seconds
# SetUB-[Notice] SetUB started
# SetUB-[Notice] SetUB successful, Duration 0.00 seconds
# SetUB-[Notice] SetUB started
# SetUB-[Notice] SetUB successful, Duration 0.00 seconds
# SetUB-[Notice] SetUB started
# SetUB-[Notice] SetUB successful, Duration 0.00 seconds
# SetUB-[Notice] SetUB started
# SetUB-[Notice] SetUB successful, Duration 0.00 seconds
# SetUB-[Notice] SetUB started
# SetUB-[Notice] SetUB successful, Duration 0.00 seconds
# SetUB-[Notice] SetUB started
# SetUB-[Notice] SetUB successful, Duration 0.00 seconds
# SetUB-[Notice] SetUB started
# SetUB-[Notice] SetUB successful, Duration 0.00 seconds
# SetUB-[Notice] SetUB started
# SetUB-[Notice] SetUB successful, Duration 0.00 seconds
# SetUB-[Notice] SetUB started
# SetUB-[Notice] SetUB successful, Duration 0.00 seconds
# SetUB-[Notice] SetUB started
# SetUB-[Notice] SetUB successful, Duration 0.00 seconds
# SetUB-[Notice] SetUB started
# SetUB-[Notice] SetUB successful, Duration 0.00 seconds
# SetUB-[Notice] SetUB started
# SetUB-[Notice] SetUB successful, Duration 0.00 seconds
# SetUB-[Notice] SetUB started
# SetUB-[Notice] SetUB successful, Duration 0.00 seconds
# SetUB-[Notice] SetUB started
# SetUB-[Notice] SetUB successful, Duration 0.00 seconds
# SetUB-[Notice] SetUB started
# SetUB-[Notice] SetUB successful, Duration 0.00 seconds
# SetUB-[Notice] SetUB started
# SetUB-[Notice] SetUB successful, Duration 0.00 seconds
# SetUB-[Notice] SetUB started
# SetUB-[Notice] SetUB successful, Duration 0.00 seconds
# SetUB-[Notice] SetUB started
# SetUB-[Notice] SetUB successful, Duration 0.00 seconds
# SetUB-[Notice] SetUB started
# SetUB-[Notice] SetUB successful, Duration 0.00 seconds
# SetUB-[Notice] SetUB started
# SetUB-[Notice] SetUB successful, Duration 0.00 seconds
# SetUB-[Notice] SetUB started
# SetUB-[Notice] SetUB successful, Duration 0.00 seconds
# SetUB-[Notice] SetUB started
# SetUB-[Notice] SetUB successful, Duration 0.00 seconds
# SetUB-[Notice] SetUB started
# SetUB-[Notice] SetUB successful, Duration 0.00 seconds
# SetUB-[Notice] SetUB started
# SetUB-[Notice] SetUB successful, Duration 0.00 seconds
# SetUB-[Notice] SetUB successful, Duration 0.06 seconds. Processed as a workspace group
# CropWorkspace-[Notice] CropWorkspace started
# CropWorkspace-[Notice] CropWorkspace started
# CropWorkspace-[Notice] CropWorkspace successful, Duration 0.61 seconds
# CropWorkspace-[Notice] CropWorkspace started
# CropWorkspace-[Notice] CropWorkspace successful, Duration 0.67 seconds
# CropWorkspace-[Notice] CropWorkspace started
# CropWorkspace-[Notice] CropWorkspace successful, Duration 0.75 seconds
# CropWorkspace-[Notice] CropWorkspace started
# CropWorkspace-[Notice] CropWorkspace successful, Duration 0.57 seconds
# CropWorkspace-[Notice] CropWorkspace started
# CropWorkspace-[Notice] CropWorkspace successful, Duration 0.59 seconds
# CropWorkspace-[Notice] CropWorkspace started
# CropWorkspace-[Notice] CropWorkspace successful, Duration 0.62 seconds
# CropWorkspace-[Notice] CropWorkspace started
# CropWorkspace-[Notice] CropWorkspace successful, Duration 0.61 seconds
# CropWorkspace-[Notice] CropWorkspace started
# CropWorkspace-[Notice] CropWorkspace successful, Duration 0.81 seconds
# CropWorkspace-[Notice] CropWorkspace started
# CropWorkspace-[Notice] CropWorkspace successful, Duration 0.85 seconds
# CropWorkspace-[Notice] CropWorkspace started
# CropWorkspace-[Notice] CropWorkspace successful, Duration 0.77 seconds
# CropWorkspace-[Notice] CropWorkspace started
# CropWorkspace-[Notice] CropWorkspace successful, Duration 0.62 seconds
# CropWorkspace-[Notice] CropWorkspace started
# CropWorkspace-[Notice] CropWorkspace successful, Duration 1.04 seconds
# CropWorkspace-[Notice] CropWorkspace started
# CropWorkspace-[Notice] CropWorkspace successful, Duration 0.59 seconds
# CropWorkspace-[Notice] CropWorkspace started
# CropWorkspace-[Notice] CropWorkspace successful, Duration 0.98 seconds
# CropWorkspace-[Notice] CropWorkspace started
# CropWorkspace-[Notice] CropWorkspace successful, Duration 0.64 seconds
# CropWorkspace-[Notice] CropWorkspace started
# CropWorkspace-[Notice] CropWorkspace successful, Duration 0.75 seconds
# CropWorkspace-[Notice] CropWorkspace started
# CropWorkspace-[Notice] CropWorkspace successful, Duration 0.98 seconds
# CropWorkspace-[Notice] CropWorkspace started
# CropWorkspace-[Notice] CropWorkspace successful, Duration 0.68 seconds
# CropWorkspace-[Notice] CropWorkspace started
# CropWorkspace-[Notice] CropWorkspace successful, Duration 0.69 seconds
# CropWorkspace-[Notice] CropWorkspace started
# CropWorkspace-[Notice] CropWorkspace successful, Duration 0.68 seconds
# CropWorkspace-[Notice] CropWorkspace started
# CropWorkspace-[Notice] CropWorkspace successful, Duration 0.63 seconds
# CropWorkspace-[Notice] CropWorkspace started
# CropWorkspace-[Notice] CropWorkspace successful, Duration 0.75 seconds
# CropWorkspace-[Notice] CropWorkspace started
# CropWorkspace-[Notice] CropWorkspace successful, Duration 0.66 seconds
# CropWorkspace-[Notice] CropWorkspace started
# CropWorkspace-[Notice] CropWorkspace successful, Duration 0.64 seconds
# CropWorkspace-[Notice] CropWorkspace started
# CropWorkspace-[Notice] CropWorkspace successful, Duration 0.79 seconds
# CropWorkspace-[Notice] CropWorkspace started
# CropWorkspace-[Notice] CropWorkspace successful, Duration 0.61 seconds
# CropWorkspace-[Notice] CropWorkspace started
# CropWorkspace-[Notice] CropWorkspace successful, Duration 0.59 seconds
# CropWorkspace-[Notice] CropWorkspace started
# CropWorkspace-[Notice] CropWorkspace successful, Duration 1.11 seconds
# CropWorkspace-[Notice] CropWorkspace started
# CropWorkspace-[Notice] CropWorkspace successful, Duration 0.67 seconds
# CropWorkspace-[Notice] CropWorkspace started
# CropWorkspace-[Notice] CropWorkspace successful, Duration 0.88 seconds
# CropWorkspace-[Notice] CropWorkspace started
# CropWorkspace-[Notice] CropWorkspace successful, Duration 0.67 seconds
# CropWorkspace-[Notice] CropWorkspace started
# CropWorkspace-[Notice] CropWorkspace successful, Duration 0.65 seconds
# CropWorkspace-[Notice] CropWorkspace started
# CropWorkspace-[Notice] CropWorkspace successful, Duration 0.58 seconds
# CropWorkspace-[Notice] CropWorkspace started
# CropWorkspace-[Notice] CropWorkspace successful, Duration 0.62 seconds
# CropWorkspace-[Notice] CropWorkspace started
# CropWorkspace-[Notice] CropWorkspace successful, Duration 0.90 seconds
# CropWorkspace-[Notice] CropWorkspace started
# CropWorkspace-[Notice] CropWorkspace successful, Duration 0.71 seconds
# CropWorkspace-[Notice] CropWorkspace started
# CropWorkspace-[Notice] CropWorkspace successful, Duration 0.64 seconds
# CropWorkspace-[Notice] CropWorkspace started
# CropWorkspace-[Notice] CropWorkspace successful, Duration 0.81 seconds
# CropWorkspace-[Notice] CropWorkspace started
# CropWorkspace-[Notice] CropWorkspace successful, Duration 0.65 seconds
# CropWorkspace-[Notice] CropWorkspace started
# CropWorkspace-[Notice] CropWorkspace successful, Duration 0.60 seconds
# CropWorkspace-[Notice] CropWorkspace started
# CropWorkspace-[Notice] CropWorkspace successful, Duration 0.68 seconds
# CropWorkspace-[Notice] CropWorkspace started
# CropWorkspace-[Notice] CropWorkspace successful, Duration 0.69 seconds
# CropWorkspace-[Notice] CropWorkspace started
# CropWorkspace-[Notice] CropWorkspace successful, Duration 0.61 seconds
# CropWorkspace-[Notice] CropWorkspace started
# CropWorkspace-[Notice] CropWorkspace successful, Duration 0.81 seconds
# CropWorkspace-[Notice] CropWorkspace started
# CropWorkspace-[Notice] CropWorkspace successful, Duration 0.70 seconds
# CropWorkspace-[Notice] CropWorkspace started
# CropWorkspace-[Notice] CropWorkspace successful, Duration 0.62 seconds
# CropWorkspace-[Notice] CropWorkspace started
# CropWorkspace-[Notice] CropWorkspace successful, Duration 0.81 seconds
# CropWorkspace-[Notice] CropWorkspace started
# CropWorkspace-[Notice] CropWorkspace successful, Duration 0.80 seconds
# CropWorkspace-[Notice] CropWorkspace started
# CropWorkspace-[Notice] CropWorkspace successful, Duration 0.61 seconds
# CropWorkspace-[Notice] CropWorkspace started
# CropWorkspace-[Notice] CropWorkspace successful, Duration 0.63 seconds
# CropWorkspace-[Notice] CropWorkspace started
# CropWorkspace-[Notice] CropWorkspace successful, Duration 0.62 seconds
# CropWorkspace-[Notice] CropWorkspace started
# CropWorkspace-[Notice] CropWorkspace successful, Duration 0.58 seconds
# CropWorkspace-[Notice] CropWorkspace started
# CropWorkspace-[Notice] CropWorkspace successful, Duration 0.62 seconds
# CropWorkspace-[Notice] CropWorkspace started
# CropWorkspace-[Notice] CropWorkspace successful, Duration 0.57 seconds
# CropWorkspace-[Notice] CropWorkspace started
# CropWorkspace-[Notice] CropWorkspace successful, Duration 0.88 seconds
# CropWorkspace-[Notice] CropWorkspace started
# CropWorkspace-[Notice] CropWorkspace successful, Duration 0.87 seconds
# CropWorkspace-[Notice] CropWorkspace started
# CropWorkspace-[Notice] CropWorkspace successful, Duration 0.58 seconds
# CropWorkspace-[Notice] CropWorkspace started
# CropWorkspace-[Notice] CropWorkspace successful, Duration 0.88 seconds
# CropWorkspace-[Notice] CropWorkspace started
# CropWorkspace-[Notice] CropWorkspace successful, Duration 0.94 seconds
# CropWorkspace-[Notice] CropWorkspace started
# CropWorkspace-[Notice] CropWorkspace successful, Duration 0.85 seconds
# CropWorkspace-[Notice] CropWorkspace started
# CropWorkspace-[Notice] CropWorkspace successful, Duration 0.94 seconds
# CropWorkspace-[Notice] CropWorkspace successful, Duration 44.35 seconds. Processed as a workspace group
# DeleteWorkspace-[Notice] DeleteWorkspace started
# DeleteWorkspace-[Notice] DeleteWorkspace started
# DeleteWorkspace-[Notice] DeleteWorkspace successful, Duration 0.00 seconds
# DeleteWorkspace-[Notice] DeleteWorkspace started
# DeleteWorkspace-[Notice] DeleteWorkspace successful, Duration 0.00 seconds
# DeleteWorkspace-[Notice] DeleteWorkspace started
# DeleteWorkspace-[Notice] DeleteWorkspace successful, Duration 0.00 seconds
# DeleteWorkspace-[Notice] DeleteWorkspace started
# DeleteWorkspace-[Notice] DeleteWorkspace successful, Duration 0.00 seconds
# DeleteWorkspace-[Notice] DeleteWorkspace started
# DeleteWorkspace-[Notice] DeleteWorkspace successful, Duration 0.00 seconds
# DeleteWorkspace-[Notice] DeleteWorkspace started
# DeleteWorkspace-[Notice] DeleteWorkspace successful, Duration 0.00 seconds
# DeleteWorkspace-[Notice] DeleteWorkspace started
# DeleteWorkspace-[Notice] DeleteWorkspace successful, Duration 0.00 seconds
# DeleteWorkspace-[Notice] DeleteWorkspace started
# DeleteWorkspace-[Notice] DeleteWorkspace successful, Duration 0.00 seconds
# DeleteWorkspace-[Notice] DeleteWorkspace started
# DeleteWorkspace-[Notice] DeleteWorkspace successful, Duration 0.00 seconds
# DeleteWorkspace-[Notice] DeleteWorkspace started
# DeleteWorkspace-[Notice] DeleteWorkspace successful, Duration 0.00 seconds
# DeleteWorkspace-[Notice] DeleteWorkspace started
# DeleteWorkspace-[Notice] DeleteWorkspace successful, Duration 0.00 seconds
# DeleteWorkspace-[Notice] DeleteWorkspace started
# DeleteWorkspace-[Notice] DeleteWorkspace successful, Duration 0.00 seconds
# DeleteWorkspace-[Notice] DeleteWorkspace started
# DeleteWorkspace-[Notice] DeleteWorkspace successful, Duration 0.00 seconds
# DeleteWorkspace-[Notice] DeleteWorkspace started
# DeleteWorkspace-[Notice] DeleteWorkspace successful, Duration 0.00 seconds
# DeleteWorkspace-[Notice] DeleteWorkspace started
# DeleteWorkspace-[Notice] DeleteWorkspace successful, Duration 0.00 seconds
# DeleteWorkspace-[Notice] DeleteWorkspace started
# DeleteWorkspace-[Notice] DeleteWorkspace successful, Duration 0.00 seconds
# DeleteWorkspace-[Notice] DeleteWorkspace started
# DeleteWorkspace-[Notice] DeleteWorkspace successful, Duration 0.00 seconds
# DeleteWorkspace-[Notice] DeleteWorkspace started
# DeleteWorkspace-[Notice] DeleteWorkspace successful, Duration 0.00 seconds
# DeleteWorkspace-[Notice] DeleteWorkspace started
# DeleteWorkspace-[Notice] DeleteWorkspace successful, Duration 0.00 seconds
# DeleteWorkspace-[Notice] DeleteWorkspace started
# DeleteWorkspace-[Notice] DeleteWorkspace successful, Duration 0.00 seconds
# DeleteWorkspace-[Notice] DeleteWorkspace started
# DeleteWorkspace-[Notice] DeleteWorkspace successful, Duration 0.00 seconds
# DeleteWorkspace-[Notice] DeleteWorkspace started
# DeleteWorkspace-[Notice] DeleteWorkspace successful, Duration 0.00 seconds
# DeleteWorkspace-[Notice] DeleteWorkspace started
# DeleteWorkspace-[Notice] DeleteWorkspace successful, Duration 0.00 seconds
# DeleteWorkspace-[Notice] DeleteWorkspace started
# DeleteWorkspace-[Notice] DeleteWorkspace successful, Duration 0.00 seconds
# DeleteWorkspace-[Notice] DeleteWorkspace started
# DeleteWorkspace-[Notice] DeleteWorkspace successful, Duration 0.00 seconds
# DeleteWorkspace-[Notice] DeleteWorkspace started
# DeleteWorkspace-[Notice] DeleteWorkspace successful, Duration 0.00 seconds
# DeleteWorkspace-[Notice] DeleteWorkspace started
# DeleteWorkspace-[Notice] DeleteWorkspace successful, Duration 0.00 seconds
# DeleteWorkspace-[Notice] DeleteWorkspace started
# DeleteWorkspace-[Notice] DeleteWorkspace successful, Duration 0.00 seconds
# DeleteWorkspace-[Notice] DeleteWorkspace started
# DeleteWorkspace-[Notice] DeleteWorkspace successful, Duration 0.00 seconds
# DeleteWorkspace-[Notice] DeleteWorkspace started
# DeleteWorkspace-[Notice] DeleteWorkspace successful, Duration 0.00 seconds
# DeleteWorkspace-[Notice] DeleteWorkspace started
# DeleteWorkspace-[Notice] DeleteWorkspace successful, Duration 0.00 seconds
# DeleteWorkspace-[Notice] DeleteWorkspace started
# DeleteWorkspace-[Notice] DeleteWorkspace successful, Duration 0.00 seconds
# DeleteWorkspace-[Notice] DeleteWorkspace started
# DeleteWorkspace-[Notice] DeleteWorkspace successful, Duration 0.00 seconds
# DeleteWorkspace-[Notice] DeleteWorkspace started
# DeleteWorkspace-[Notice] DeleteWorkspace successful, Duration 0.00 seconds
# DeleteWorkspace-[Notice] DeleteWorkspace started
# DeleteWorkspace-[Notice] DeleteWorkspace successful, Duration 0.00 seconds
# DeleteWorkspace-[Notice] DeleteWorkspace started
# DeleteWorkspace-[Notice] DeleteWorkspace successful, Duration 0.00 seconds
# DeleteWorkspace-[Notice] DeleteWorkspace started
# DeleteWorkspace-[Notice] DeleteWorkspace successful, Duration 0.00 seconds
# DeleteWorkspace-[Notice] DeleteWorkspace started
# DeleteWorkspace-[Notice] DeleteWorkspace successful, Duration 0.00 seconds
# DeleteWorkspace-[Notice] DeleteWorkspace started
# DeleteWorkspace-[Notice] DeleteWorkspace successful, Duration 0.00 seconds
# DeleteWorkspace-[Notice] DeleteWorkspace started
# DeleteWorkspace-[Notice] DeleteWorkspace successful, Duration 0.00 seconds
# DeleteWorkspace-[Notice] DeleteWorkspace started
# DeleteWorkspace-[Notice] DeleteWorkspace successful, Duration 0.00 seconds
# DeleteWorkspace-[Notice] DeleteWorkspace started
# DeleteWorkspace-[Notice] DeleteWorkspace successful, Duration 0.00 seconds
# DeleteWorkspace-[Notice] DeleteWorkspace started
# DeleteWorkspace-[Notice] DeleteWorkspace successful, Duration 0.00 seconds
# DeleteWorkspace-[Notice] DeleteWorkspace started
# DeleteWorkspace-[Notice] DeleteWorkspace successful, Duration 0.00 seconds
# DeleteWorkspace-[Notice] DeleteWorkspace started
# DeleteWorkspace-[Notice] DeleteWorkspace successful, Duration 0.00 seconds
# DeleteWorkspace-[Notice] DeleteWorkspace started
# DeleteWorkspace-[Notice] DeleteWorkspace successful, Duration 0.00 seconds
# DeleteWorkspace-[Notice] DeleteWorkspace started
# DeleteWorkspace-[Notice] DeleteWorkspace successful, Duration 0.00 seconds
# DeleteWorkspace-[Notice] DeleteWorkspace started
# DeleteWorkspace-[Notice] DeleteWorkspace successful, Duration 0.00 seconds
# DeleteWorkspace-[Notice] DeleteWorkspace started
# DeleteWorkspace-[Notice] DeleteWorkspace successful, Duration 0.00 seconds
# DeleteWorkspace-[Notice] DeleteWorkspace started
# DeleteWorkspace-[Notice] DeleteWorkspace successful, Duration 0.00 seconds
# DeleteWorkspace-[Notice] DeleteWorkspace started
# DeleteWorkspace-[Notice] DeleteWorkspace successful, Duration 0.00 seconds
# DeleteWorkspace-[Notice] DeleteWorkspace started
# DeleteWorkspace-[Notice] DeleteWorkspace successful, Duration 0.00 seconds
# DeleteWorkspace-[Notice] DeleteWorkspace started
# DeleteWorkspace-[Notice] DeleteWorkspace successful, Duration 0.00 seconds
# DeleteWorkspace-[Notice] DeleteWorkspace started
# DeleteWorkspace-[Notice] DeleteWorkspace successful, Duration 0.00 seconds
# DeleteWorkspace-[Notice] DeleteWorkspace started
# DeleteWorkspace-[Notice] DeleteWorkspace successful, Duration 0.00 seconds
# DeleteWorkspace-[Notice] DeleteWorkspace started
# DeleteWorkspace-[Notice] DeleteWorkspace successful, Duration 0.00 seconds
# DeleteWorkspace-[Notice] DeleteWorkspace started
# DeleteWorkspace-[Notice] DeleteWorkspace successful, Duration 0.00 seconds
# DeleteWorkspace-[Notice] DeleteWorkspace started
# DeleteWorkspace-[Notice] DeleteWorkspace successful, Duration 0.00 seconds
# DeleteWorkspace-[Notice] DeleteWorkspace started
# DeleteWorkspace-[Notice] DeleteWorkspace successful, Duration 0.00 seconds
# DeleteWorkspace-[Notice] DeleteWorkspace started
# DeleteWorkspace-[Notice] DeleteWorkspace successful, Duration 0.00 seconds
# DeleteWorkspace-[Notice] DeleteWorkspace started
# DeleteWorkspace-[Notice] DeleteWorkspace successful, Duration 0.00 seconds
# DeleteWorkspace-[Notice] DeleteWorkspace successful, Duration 0.02 seconds. Processed as a workspace group
# ConvertToMD-[Notice] ConvertToMD started
# ConvertToMD-[Notice] ConvertToMD successful, Duration 2.39 seconds
# {'AlignedDim1': 'DeltaE,0,90, 180', 'AlignedDim0': '[H,0,0],-2.1,0.1,56', 'AlignedDim3': '[0,0,L],-1,1,1', 'AlignedDim2': '[0,K,0],-1,1,1'}
# MDNormDirectSC-[Notice] MDNormDirectSC started
# MDNormDirectSC-[Notice] MDNormDirectSC successful, Duration 0.72 seconds
# rotation angle #0: -90.0
# CloneMDWorkspace-[Notice] CloneMDWorkspace started
# CloneMDWorkspace-[Notice] CloneMDWorkspace successful, Duration 0.00 seconds
# CloneMDWorkspace-[Notice] CloneMDWorkspace started
# CloneMDWorkspace-[Notice] CloneMDWorkspace successful, Duration 0.00 seconds
# ConvertToMD-[Notice] ConvertToMD started
# ConvertToMD-[Notice] ConvertToMD successful, Duration 0.42 seconds
# {'AlignedDim1': 'DeltaE,0,90, 180', 'AlignedDim0': '[H,0,0],-2.1,0.1,56', 'AlignedDim3': '[0,0,L],-1,1,1', 'AlignedDim2': '[0,K,0],-1,1,1'}
# MDNormDirectSC-[Notice] MDNormDirectSC started
# MDNormDirectSC-[Notice] MDNormDirectSC successful, Duration 0.63 seconds
# rotation angle #1: -87.0
# PlusMD-[Notice] PlusMD started
# PlusMD-[Notice] PlusMD successful, Duration 0.00 seconds
# PlusMD-[Notice] PlusMD started
# PlusMD-[Notice] PlusMD successful, Duration 0.01 seconds
# ConvertToMD-[Notice] ConvertToMD started
# ConvertToMD-[Notice] ConvertToMD successful, Duration 0.47 seconds
# {'AlignedDim1': 'DeltaE,0,90, 180', 'AlignedDim0': '[H,0,0],-2.1,0.1,56', 'AlignedDim3': '[0,0,L],-1,1,1', 'AlignedDim2': '[0,K,0],-1,1,1'}
# MDNormDirectSC-[Notice] MDNormDirectSC started
# MDNormDirectSC-[Notice] MDNormDirectSC successful, Duration 0.48 seconds
# rotation angle #2: -84.0
# PlusMD-[Notice] PlusMD started
# PlusMD-[Notice] PlusMD successful, Duration 0.00 seconds
# PlusMD-[Notice] PlusMD started
# PlusMD-[Notice] PlusMD successful, Duration 0.00 seconds
# ConvertToMD-[Notice] ConvertToMD started
# ConvertToMD-[Notice] ConvertToMD successful, Duration 0.33 seconds
# {'AlignedDim1': 'DeltaE,0,90, 180', 'AlignedDim0': '[H,0,0],-2.1,0.1,56', 'AlignedDim3': '[0,0,L],-1,1,1', 'AlignedDim2': '[0,K,0],-1,1,1'}
# MDNormDirectSC-[Notice] MDNormDirectSC started
# MDNormDirectSC-[Notice] MDNormDirectSC successful, Duration 0.88 seconds
# rotation angle #3: -81.0
# PlusMD-[Notice] PlusMD started
# PlusMD-[Notice] PlusMD successful, Duration 0.00 seconds
# PlusMD-[Notice] PlusMD started
# PlusMD-[Notice] PlusMD successful, Duration 0.00 seconds
# ConvertToMD-[Notice] ConvertToMD started
# ConvertToMD-[Notice] ConvertToMD successful, Duration 0.28 seconds
# {'AlignedDim1': 'DeltaE,0,90, 180', 'AlignedDim0': '[H,0,0],-2.1,0.1,56', 'AlignedDim3': '[0,0,L],-1,1,1', 'AlignedDim2': '[0,K,0],-1,1,1'}
# MDNormDirectSC-[Notice] MDNormDirectSC started
# MDNormDirectSC-[Notice] MDNormDirectSC successful, Duration 0.52 seconds
# rotation angle #4: -78.0
# PlusMD-[Notice] PlusMD started
# PlusMD-[Notice] PlusMD successful, Duration 0.00 seconds
# PlusMD-[Notice] PlusMD started
# PlusMD-[Notice] PlusMD successful, Duration 0.00 seconds
# ConvertToMD-[Notice] ConvertToMD started
# ConvertToMD-[Notice] ConvertToMD successful, Duration 0.30 seconds
# {'AlignedDim1': 'DeltaE,0,90, 180', 'AlignedDim0': '[H,0,0],-2.1,0.1,56', 'AlignedDim3': '[0,0,L],-1,1,1', 'AlignedDim2': '[0,K,0],-1,1,1'}
# MDNormDirectSC-[Notice] MDNormDirectSC started
# MDNormDirectSC-[Notice] MDNormDirectSC successful, Duration 0.73 seconds
# rotation angle #5: -75.0
# PlusMD-[Notice] PlusMD started
# PlusMD-[Notice] PlusMD successful, Duration 0.00 seconds
# PlusMD-[Notice] PlusMD started
# PlusMD-[Notice] PlusMD successful, Duration 0.00 seconds
# ConvertToMD-[Notice] ConvertToMD started
# ConvertToMD-[Notice] ConvertToMD successful, Duration 0.25 seconds
# {'AlignedDim1': 'DeltaE,0,90, 180', 'AlignedDim0': '[H,0,0],-2.1,0.1,56', 'AlignedDim3': '[0,0,L],-1,1,1', 'AlignedDim2': '[0,K,0],-1,1,1'}
# MDNormDirectSC-[Notice] MDNormDirectSC started
# MDNormDirectSC-[Notice] MDNormDirectSC successful, Duration 0.48 seconds
# rotation angle #6: -72.0
# PlusMD-[Notice] PlusMD started
# PlusMD-[Notice] PlusMD successful, Duration 0.00 seconds
# PlusMD-[Notice] PlusMD started
# PlusMD-[Notice] PlusMD successful, Duration 0.00 seconds
# ConvertToMD-[Notice] ConvertToMD started
# ConvertToMD-[Notice] ConvertToMD successful, Duration 0.49 seconds
# {'AlignedDim1': 'DeltaE,0,90, 180', 'AlignedDim0': '[H,0,0],-2.1,0.1,56', 'AlignedDim3': '[0,0,L],-1,1,1', 'AlignedDim2': '[0,K,0],-1,1,1'}
# MDNormDirectSC-[Notice] MDNormDirectSC started
# MDNormDirectSC-[Notice] MDNormDirectSC successful, Duration 0.69 seconds
# rotation angle #7: -69.0
# PlusMD-[Notice] PlusMD started
# PlusMD-[Notice] PlusMD successful, Duration 0.00 seconds
# PlusMD-[Notice] PlusMD started
# PlusMD-[Notice] PlusMD successful, Duration 0.00 seconds
# ConvertToMD-[Notice] ConvertToMD started
# ConvertToMD-[Notice] ConvertToMD successful, Duration 0.54 seconds
# {'AlignedDim1': 'DeltaE,0,90, 180', 'AlignedDim0': '[H,0,0],-2.1,0.1,56', 'AlignedDim3': '[0,0,L],-1,1,1', 'AlignedDim2': '[0,K,0],-1,1,1'}
# MDNormDirectSC-[Notice] MDNormDirectSC started
# MDNormDirectSC-[Notice] MDNormDirectSC successful, Duration 0.48 seconds
# rotation angle #8: -66.0
# PlusMD-[Notice] PlusMD started
# ...
# {'AlignedDim1': 'DeltaE,0,90, 180', 'AlignedDim0': '[H,0,0],-2.1,0.1,56', 'AlignedDim3': '[0,0,L],-1,1,1', 'AlignedDim2': '[0,K,0],-1,1,1'}
# MDNormDirectSC-[Notice] MDNormDirectSC started
# MDNormDirectSC-[Notice] MDNormDirectSC successful, Duration 1.09 seconds
# rotation angle #34: 12.0
# PlusMD-[Notice] PlusMD started
# PlusMD-[Notice] PlusMD successful, Duration 0.00 seconds
# PlusMD-[Notice] PlusMD started
# PlusMD-[Notice] PlusMD successful, Duration 0.00 seconds
# ConvertToMD-[Notice] ConvertToMD started
# ConvertToMD-[Notice] ConvertToMD successful, Duration 0.32 seconds
# {'AlignedDim1': 'DeltaE,0,90, 180', 'AlignedDim0': '[H,0,0],-2.1,0.1,56', 'AlignedDim3': '[0,0,L],-1,1,1', 'AlignedDim2': '[0,K,0],-1,1,1'}
# MDNormDirectSC-[Notice] MDNormDirectSC started
# MDNormDirectSC-[Notice] MDNormDirectSC successful, Duration 1.17 seconds
# rotation angle #35: 15.0
# PlusMD-[Notice] PlusMD started
# PlusMD-[Notice] PlusMD successful, Duration 0.00 seconds
# PlusMD-[Notice] PlusMD started
# PlusMD-[Notice] PlusMD successful, Duration 0.00 seconds
# ConvertToMD-[Notice] ConvertToMD started
# ConvertToMD-[Notice] ConvertToMD successful, Duration 0.33 seconds
# {'AlignedDim1': 'DeltaE,0,90, 180', 'AlignedDim0': '[H,0,0],-2.1,0.1,56', 'AlignedDim3': '[0,0,L],-1,1,1', 'AlignedDim2': '[0,K,0],-1,1,1'}
# MDNormDirectSC-[Notice] MDNormDirectSC started
# MDNormDirectSC-[Notice] MDNormDirectSC successful, Duration 1.42 seconds
# rotation angle #36: 18.0
# PlusMD-[Notice] PlusMD started
# PlusMD-[Notice] PlusMD successful, Duration 0.00 seconds
# PlusMD-[Notice] PlusMD started
# PlusMD-[Notice] PlusMD successful, Duration 0.00 seconds
# ConvertToMD-[Notice] ConvertToMD started
# ConvertToMD-[Notice] ConvertToMD successful, Duration 0.35 seconds
# {'AlignedDim1': 'DeltaE,0,90, 180', 'AlignedDim0': '[H,0,0],-2.1,0.1,56', 'AlignedDim3': '[0,0,L],-1,1,1', 'AlignedDim2': '[0,K,0],-1,1,1'}
# MDNormDirectSC-[Notice] MDNormDirectSC started
# MDNormDirectSC-[Notice] MDNormDirectSC successful, Duration 1.58 seconds
# rotation angle #37: 21.0
# PlusMD-[Notice] PlusMD started
# PlusMD-[Notice] PlusMD successful, Duration 0.00 seconds
# PlusMD-[Notice] PlusMD started
# PlusMD-[Notice] PlusMD successful, Duration 0.00 seconds
# ConvertToMD-[Notice] ConvertToMD started
# ConvertToMD-[Notice] ConvertToMD successful, Duration 0.37 seconds
# {'AlignedDim1': 'DeltaE,0,90, 180', 'AlignedDim0': '[H,0,0],-2.1,0.1,56', 'AlignedDim3': '[0,0,L],-1,1,1', 'AlignedDim2': '[0,K,0],-1,1,1'}
# MDNormDirectSC-[Notice] MDNormDirectSC started
# MDNormDirectSC-[Notice] MDNormDirectSC successful, Duration 1.67 seconds
# rotation angle #38: 24.0
# PlusMD-[Notice] PlusMD started
# PlusMD-[Notice] PlusMD successful, Duration 0.00 seconds
# PlusMD-[Notice] PlusMD started
# PlusMD-[Notice] PlusMD successful, Duration 0.00 seconds
# ConvertToMD-[Notice] ConvertToMD started
# ConvertToMD-[Notice] ConvertToMD successful, Duration 0.33 seconds
# {'AlignedDim1': 'DeltaE,0,90, 180', 'AlignedDim0': '[H,0,0],-2.1,0.1,56', 'AlignedDim3': '[0,0,L],-1,1,1', 'AlignedDim2': '[0,K,0],-1,1,1'}
# MDNormDirectSC-[Notice] MDNormDirectSC started
# MDNormDirectSC-[Notice] MDNormDirectSC successful, Duration 1.72 seconds
# rotation angle #39: 27.0
# PlusMD-[Notice] PlusMD started
# PlusMD-[Notice] PlusMD successful, Duration 0.00 seconds
# PlusMD-[Notice] PlusMD started
# PlusMD-[Notice] PlusMD successful, Duration 0.00 seconds
# ConvertToMD-[Notice] ConvertToMD started
# ConvertToMD-[Notice] ConvertToMD successful, Duration 0.30 seconds
# {'AlignedDim1': 'DeltaE,0,90, 180', 'AlignedDim0': '[H,0,0],-2.1,0.1,56', 'AlignedDim3': '[0,0,L],-1,1,1', 'AlignedDim2': '[0,K,0],-1,1,1'}
# MDNormDirectSC-[Notice] MDNormDirectSC started
# MDNormDirectSC-[Notice] MDNormDirectSC successful, Duration 1.78 seconds
# rotation angle #40: 30.0
# PlusMD-[Notice] PlusMD started
# PlusMD-[Notice] PlusMD successful, Duration 0.00 seconds
# PlusMD-[Notice] PlusMD started
# PlusMD-[Notice] PlusMD successful, Duration 0.00 seconds
# ConvertToMD-[Notice] ConvertToMD started
# ConvertToMD-[Notice] ConvertToMD successful, Duration 0.28 seconds
# {'AlignedDim1': 'DeltaE,0,90, 180', 'AlignedDim0': '[H,0,0],-2.1,0.1,56', 'AlignedDim3': '[0,0,L],-1,1,1', 'AlignedDim2': '[0,K,0],-1,1,1'}
# MDNormDirectSC-[Notice] MDNormDirectSC started
# MDNormDirectSC-[Notice] MDNormDirectSC successful, Duration 1.97 seconds
# rotation angle #41: 33.0
# PlusMD-[Notice] PlusMD started
# PlusMD-[Notice] PlusMD successful, Duration 0.00 seconds
# PlusMD-[Notice] PlusMD started
# PlusMD-[Notice] PlusMD successful, Duration 0.00 seconds
# ConvertToMD-[Notice] ConvertToMD started
# ConvertToMD-[Notice] ConvertToMD successful, Duration 0.28 seconds
# {'AlignedDim1': 'DeltaE,0,90, 180', 'AlignedDim0': '[H,0,0],-2.1,0.1,56', 'AlignedDim3': '[0,0,L],-1,1,1', 'AlignedDim2': '[0,K,0],-1,1,1'}
# MDNormDirectSC-[Notice] MDNormDirectSC started
# MDNormDirectSC-[Notice] MDNormDirectSC successful, Duration 2.27 seconds
# rotation angle #42: 36.0
# PlusMD-[Notice] PlusMD started
# PlusMD-[Notice] PlusMD successful, Duration 0.00 seconds
# PlusMD-[Notice] PlusMD started
# PlusMD-[Notice] PlusMD successful, Duration 0.00 seconds
# ConvertToMD-[Notice] ConvertToMD started
# ConvertToMD-[Notice] ConvertToMD successful, Duration 0.28 seconds
# {'AlignedDim1': 'DeltaE,0,90, 180', 'AlignedDim0': '[H,0,0],-2.1,0.1,56', 'AlignedDim3': '[0,0,L],-1,1,1', 'AlignedDim2': '[0,K,0],-1,1,1'}
# MDNormDirectSC-[Notice] MDNormDirectSC started
# MDNormDirectSC-[Notice] MDNormDirectSC successful, Duration 2.61 seconds
# rotation angle #43: 39.0
# PlusMD-[Notice] PlusMD started
# PlusMD-[Notice] PlusMD successful, Duration 0.00 seconds
# PlusMD-[Notice] PlusMD started
# PlusMD-[Notice] PlusMD successful, Duration 0.00 seconds
# ConvertToMD-[Notice] ConvertToMD started
# ConvertToMD-[Notice] ConvertToMD successful, Duration 0.23 seconds
# {'AlignedDim1': 'DeltaE,0,90, 180', 'AlignedDim0': '[H,0,0],-2.1,0.1,56', 'AlignedDim3': '[0,0,L],-1,1,1', 'AlignedDim2': '[0,K,0],-1,1,1'}
# MDNormDirectSC-[Notice] MDNormDirectSC started
# MDNormDirectSC-[Notice] MDNormDirectSC successful, Duration 2.67 seconds
# rotation angle #44: 42.0
# PlusMD-[Notice] PlusMD started
# PlusMD-[Notice] PlusMD successful, Duration 0.00 seconds
# PlusMD-[Notice] PlusMD started
# PlusMD-[Notice] PlusMD successful, Duration 0.00 seconds
# ConvertToMD-[Notice] ConvertToMD started
# ConvertToMD-[Notice] ConvertToMD successful, Duration 0.31 seconds
# {'AlignedDim1': 'DeltaE,0,90, 180', 'AlignedDim0': '[H,0,0],-2.1,0.1,56', 'AlignedDim3': '[0,0,L],-1,1,1', 'AlignedDim2': '[0,K,0],-1,1,1'}
# MDNormDirectSC-[Notice] MDNormDirectSC started
# MDNormDirectSC-[Notice] MDNormDirectSC successful, Duration 2.99 seconds
# rotation angle #45: 45.0
# PlusMD-[Notice] PlusMD started
# PlusMD-[Notice] PlusMD successful, Duration 0.00 seconds
# PlusMD-[Notice] PlusMD started
# PlusMD-[Notice] PlusMD successful, Duration 0.00 seconds
# ConvertToMD-[Notice] ConvertToMD started
# ConvertToMD-[Notice] ConvertToMD successful, Duration 0.34 seconds
# {'AlignedDim1': 'DeltaE,0,90, 180', 'AlignedDim0': '[H,0,0],-2.1,0.1,56', 'AlignedDim3': '[0,0,L],-1,1,1', 'AlignedDim2': '[0,K,0],-1,1,1'}
# MDNormDirectSC-[Notice] MDNormDirectSC started
# MDNormDirectSC-[Notice] MDNormDirectSC successful, Duration 3.70 seconds
# rotation angle #46: 48.0
# PlusMD-[Notice] PlusMD started
# PlusMD-[Notice] PlusMD successful, Duration 0.00 seconds
# PlusMD-[Notice] PlusMD started
# PlusMD-[Notice] PlusMD successful, Duration 0.00 seconds
# ConvertToMD-[Notice] ConvertToMD started
# ConvertToMD-[Notice] ConvertToMD successful, Duration 0.25 seconds
# {'AlignedDim1': 'DeltaE,0,90, 180', 'AlignedDim0': '[H,0,0],-2.1,0.1,56', 'AlignedDim3': '[0,0,L],-1,1,1', 'AlignedDim2': '[0,K,0],-1,1,1'}
# MDNormDirectSC-[Notice] MDNormDirectSC started
# MDNormDirectSC-[Notice] MDNormDirectSC successful, Duration 3.74 seconds
# rotation angle #47: 51.0
# PlusMD-[Notice] PlusMD started
# PlusMD-[Notice] PlusMD successful, Duration 0.00 seconds
# PlusMD-[Notice] PlusMD started
# PlusMD-[Notice] PlusMD successful, Duration 0.00 seconds
# ConvertToMD-[Notice] ConvertToMD started
# ConvertToMD-[Notice] ConvertToMD successful, Duration 0.32 seconds
# {'AlignedDim1': 'DeltaE,0,90, 180', 'AlignedDim0': '[H,0,0],-2.1,0.1,56', 'AlignedDim3': '[0,0,L],-1,1,1', 'AlignedDim2': '[0,K,0],-1,1,1'}
# MDNormDirectSC-[Notice] MDNormDirectSC started
# MDNormDirectSC-[Notice] MDNormDirectSC successful, Duration 4.16 seconds
# rotation angle #48: 54.0
# PlusMD-[Notice] PlusMD started
# PlusMD-[Notice] PlusMD successful, Duration 0.00 seconds
# PlusMD-[Notice] PlusMD started
# PlusMD-[Notice] PlusMD successful, Duration 0.00 seconds
# ConvertToMD-[Notice] ConvertToMD started
# ConvertToMD-[Notice] ConvertToMD successful, Duration 0.22 seconds
# {'AlignedDim1': 'DeltaE,0,90, 180', 'AlignedDim0': '[H,0,0],-2.1,0.1,56', 'AlignedDim3': '[0,0,L],-1,1,1', 'AlignedDim2': '[0,K,0],-1,1,1'}
# MDNormDirectSC-[Notice] MDNormDirectSC started
# MDNormDirectSC-[Notice] MDNormDirectSC successful, Duration 4.65 seconds
# rotation angle #49: 57.0
# PlusMD-[Notice] PlusMD started
# PlusMD-[Notice] PlusMD successful, Duration 0.00 seconds
# PlusMD-[Notice] PlusMD started
# PlusMD-[Notice] PlusMD successful, Duration 0.00 seconds
# ConvertToMD-[Notice] ConvertToMD started
# ConvertToMD-[Notice] ConvertToMD successful, Duration 0.29 seconds
# {'AlignedDim1': 'DeltaE,0,90, 180', 'AlignedDim0': '[H,0,0],-2.1,0.1,56', 'AlignedDim3': '[0,0,L],-1,1,1', 'AlignedDim2': '[0,K,0],-1,1,1'}
# MDNormDirectSC-[Notice] MDNormDirectSC started
# MDNormDirectSC-[Notice] MDNormDirectSC successful, Duration 5.08 seconds
# rotation angle #50: 60.0
# PlusMD-[Notice] PlusMD started
# PlusMD-[Notice] PlusMD successful, Duration 0.00 seconds
# PlusMD-[Notice] PlusMD started
# PlusMD-[Notice] PlusMD successful, Duration 0.00 seconds
# ConvertToMD-[Notice] ConvertToMD started
# ConvertToMD-[Notice] ConvertToMD successful, Duration 0.23 seconds
# {'AlignedDim1': 'DeltaE,0,90, 180', 'AlignedDim0': '[H,0,0],-2.1,0.1,56', 'AlignedDim3': '[0,0,L],-1,1,1', 'AlignedDim2': '[0,K,0],-1,1,1'}
# MDNormDirectSC-[Notice] MDNormDirectSC started
# MDNormDirectSC-[Notice] MDNormDirectSC successful, Duration 5.40 seconds
# rotation angle #51: 63.0
# PlusMD-[Notice] PlusMD started
# PlusMD-[Notice] PlusMD successful, Duration 0.00 seconds
# PlusMD-[Notice] PlusMD started
# PlusMD-[Notice] PlusMD successful, Duration 0.00 seconds
# ConvertToMD-[Notice] ConvertToMD started
# ConvertToMD-[Notice] ConvertToMD successful, Duration 0.25 seconds
# {'AlignedDim1': 'DeltaE,0,90, 180', 'AlignedDim0': '[H,0,0],-2.1,0.1,56', 'AlignedDim3': '[0,0,L],-1,1,1', 'AlignedDim2': '[0,K,0],-1,1,1'}
# MDNormDirectSC-[Notice] MDNormDirectSC started
# MDNormDirectSC-[Notice] MDNormDirectSC successful, Duration 5.98 seconds
# rotation angle #52: 66.0
# PlusMD-[Notice] PlusMD started
# PlusMD-[Notice] PlusMD successful, Duration 0.00 seconds
# PlusMD-[Notice] PlusMD started
# PlusMD-[Notice] PlusMD successful, Duration 0.00 seconds
# ConvertToMD-[Notice] ConvertToMD started
# ConvertToMD-[Notice] ConvertToMD successful, Duration 0.29 seconds
# {'AlignedDim1': 'DeltaE,0,90, 180', 'AlignedDim0': '[H,0,0],-2.1,0.1,56', 'AlignedDim3': '[0,0,L],-1,1,1', 'AlignedDim2': '[0,K,0],-1,1,1'}
# MDNormDirectSC-[Notice] MDNormDirectSC started
# MDNormDirectSC-[Notice] MDNormDirectSC successful, Duration 6.26 seconds
# rotation angle #53: 69.0
# PlusMD-[Notice] PlusMD started
# PlusMD-[Notice] PlusMD successful, Duration 0.00 seconds
# PlusMD-[Notice] PlusMD started
# PlusMD-[Notice] PlusMD successful, Duration 0.00 seconds
# ConvertToMD-[Notice] ConvertToMD started
# ConvertToMD-[Notice] ConvertToMD successful, Duration 0.21 seconds
# {'AlignedDim1': 'DeltaE,0,90, 180', 'AlignedDim0': '[H,0,0],-2.1,0.1,56', 'AlignedDim3': '[0,0,L],-1,1,1', 'AlignedDim2': '[0,K,0],-1,1,1'}
# MDNormDirectSC-[Notice] MDNormDirectSC started
# MDNormDirectSC-[Notice] MDNormDirectSC successful, Duration 6.74 seconds
# rotation angle #54: 72.0
# PlusMD-[Notice] PlusMD started
# PlusMD-[Notice] PlusMD successful, Duration 0.00 seconds
# PlusMD-[Notice] PlusMD started
# PlusMD-[Notice] PlusMD successful, Duration 0.00 seconds
# ConvertToMD-[Notice] ConvertToMD started
# ConvertToMD-[Notice] ConvertToMD successful, Duration 0.20 seconds
# {'AlignedDim1': 'DeltaE,0,90, 180', 'AlignedDim0': '[H,0,0],-2.1,0.1,56', 'AlignedDim3': '[0,0,L],-1,1,1', 'AlignedDim2': '[0,K,0],-1,1,1'}
# MDNormDirectSC-[Notice] MDNormDirectSC started
# MDNormDirectSC-[Notice] MDNormDirectSC successful, Duration 7.32 seconds
# rotation angle #55: 75.0
# PlusMD-[Notice] PlusMD started
# PlusMD-[Notice] PlusMD successful, Duration 0.00 seconds
# PlusMD-[Notice] PlusMD started
# PlusMD-[Notice] PlusMD successful, Duration 0.00 seconds
# ConvertToMD-[Notice] ConvertToMD started
# ConvertToMD-[Notice] ConvertToMD successful, Duration 0.20 seconds
# {'AlignedDim1': 'DeltaE,0,90, 180', 'AlignedDim0': '[H,0,0],-2.1,0.1,56', 'AlignedDim3': '[0,0,L],-1,1,1', 'AlignedDim2': '[0,K,0],-1,1,1'}
# MDNormDirectSC-[Notice] MDNormDirectSC started
# MDNormDirectSC-[Notice] MDNormDirectSC successful, Duration 7.60 seconds
# rotation angle #56: 78.0
# PlusMD-[Notice] PlusMD started
# PlusMD-[Notice] PlusMD successful, Duration 0.00 seconds
# PlusMD-[Notice] PlusMD started
# PlusMD-[Notice] PlusMD successful, Duration 0.00 seconds
# ConvertToMD-[Notice] ConvertToMD started
# ConvertToMD-[Notice] ConvertToMD successful, Duration 0.27 seconds
# {'AlignedDim1': 'DeltaE,0,90, 180', 'AlignedDim0': '[H,0,0],-2.1,0.1,56', 'AlignedDim3': '[0,0,L],-1,1,1', 'AlignedDim2': '[0,K,0],-1,1,1'}
# MDNormDirectSC-[Notice] MDNormDirectSC started
# MDNormDirectSC-[Notice] MDNormDirectSC successful, Duration 8.27 seconds
# rotation angle #57: 81.0
# PlusMD-[Notice] PlusMD started
# PlusMD-[Notice] PlusMD successful, Duration 0.00 seconds
# PlusMD-[Notice] PlusMD started
# PlusMD-[Notice] PlusMD successful, Duration 0.00 seconds
# ConvertToMD-[Notice] ConvertToMD started
# ConvertToMD-[Notice] ConvertToMD successful, Duration 0.21 seconds
# {'AlignedDim1': 'DeltaE,0,90, 180', 'AlignedDim0': '[H,0,0],-2.1,0.1,56', 'AlignedDim3': '[0,0,L],-1,1,1', 'AlignedDim2': '[0,K,0],-1,1,1'}
# MDNormDirectSC-[Notice] MDNormDirectSC started
# MDNormDirectSC-[Notice] MDNormDirectSC successful, Duration 8.78 seconds
# rotation angle #58: 84.0
# PlusMD-[Notice] PlusMD started
# PlusMD-[Notice] PlusMD successful, Duration 0.00 seconds
# PlusMD-[Notice] PlusMD started
# PlusMD-[Notice] PlusMD successful, Duration 0.00 seconds
# ConvertToMD-[Notice] ConvertToMD started
# ConvertToMD-[Notice] ConvertToMD successful, Duration 0.19 seconds
# {'AlignedDim1': 'DeltaE,0,90, 180', 'AlignedDim0': '[H,0,0],-2.1,0.1,56', 'AlignedDim3': '[0,0,L],-1,1,1', 'AlignedDim2': '[0,K,0],-1,1,1'}
# MDNormDirectSC-[Notice] MDNormDirectSC started
# MDNormDirectSC-[Notice] MDNormDirectSC successful, Duration 9.12 seconds
# rotation angle #59: 87.0
# PlusMD-[Notice] PlusMD started
# PlusMD-[Notice] PlusMD successful, Duration 0.00 seconds
# PlusMD-[Notice] PlusMD started
# PlusMD-[Notice] PlusMD successful, Duration 0.00 seconds
# ConvertToMD-[Notice] ConvertToMD started
# ConvertToMD-[Notice] ConvertToMD successful, Duration 0.19 seconds
# {'AlignedDim1': 'DeltaE,0,90, 180', 'AlignedDim0': '[H,0,0],-2.1,0.1,56', 'AlignedDim3': '[0,0,L],-1,1,1', 'AlignedDim2': '[0,K,0],-1,1,1'}
# MDNormDirectSC-[Notice] MDNormDirectSC started
# MDNormDirectSC-[Notice] MDNormDirectSC successful, Duration 9.15 seconds
# rotation angle #60: 90.0
# PlusMD-[Notice] PlusMD started
# PlusMD-[Notice] PlusMD successful, Duration 0.00 seconds
# PlusMD-[Notice] PlusMD started
# PlusMD-[Notice] PlusMD successful, Duration 0.00 seconds
# RemoveWorkspaceHistory-[Notice] RemoveWorkspaceHistory started
# RemoveWorkspaceHistory-[Notice] RemoveWorkspaceHistory successful, Duration 0.00 seconds
# RemoveWorkspaceHistory-[Notice] RemoveWorkspaceHistory started
# RemoveWorkspaceHistory-[Notice] RemoveWorkspaceHistory successful, Duration 0.01 seconds
# SmoothMD-[Notice] SmoothMD started
# SmoothMD-[Notice] SmoothMD successful, Duration 0.01 seconds
# SmoothMD-[Notice] SmoothMD started
# SmoothMD-[Notice] SmoothMD successful, Duration 0.00 seconds
# DivideMD-[Notice] DivideMD started
# DivideMD-[Notice] DivideMD successful, Duration 0.00 seconds
# SaveMD-[Notice] SaveMD started
# SaveMD-[Notice] SaveMD successful, Duration 0.73 seconds

# %%
# !./scripts/reduce/slice2hist.py "slice_H00_-2__0.nxs" slice_H00_-2,0.h5
# Out:
# FrameworkManager-[Notice] Welcome to Mantid 3.6.100
# FrameworkManager-[Notice] Please cite: http://dx.doi.org/10.1016/j.nima.2014.07.029 and this release: http://dx.doi.org/10.5286/Software/Mantid3.6.100
# Load-[Notice] Load started
# Load-[Notice] Load successful, Duration 1.35 seconds

# %%
H.plot(hh.load("./slice_H00_-2,0.h5"), min=0, max=1e-6)
# Out:
# plot z in (0, 1e-06)
# <img src="data:image/png;base64,...">
